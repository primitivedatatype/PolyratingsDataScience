# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from IPython.display import display
import time

# %% [markdown]
# ## Organization Strategy: How Can We Store Info on Polyratings?
#
# ### Entities & Features
#
#  Entities/Objects
#  * Professors
#  * Reviews
#  * Courses
#
#  Attributes/Features
#  * Grades earned by reviewers
#  * The Year level (Freshman, Sophomore, etc.) of the reviewers
#  * Course
#  * Department
#  * Professor Abilities
#      * Overall Rating
#      * Presents Material Clearly
#      * Understands Student Difficulties
#  * Number of Reporting Evaluations/Reviews
#
# ### review_id:
# Many of the statistics are based on the individual sample reviews. These are conveniently accompanied by a 'comment id' in the html of Polyratings.com.
#
# ### prof_id:
# The professors each have their own review page and full statistical analysis page. Both of the urls for these pages end with a unique number. Let's use this as a professor id.

# %%
def get_prof_id(url): 
    '''
    Finds a Professor's Id, as specified in the url.
    Example: with the url: http://polyratings.com/eval.phtml?profid=2073
                prof_id is: 2073
    
    Args: 
        url (string)
    Returns:
        prof_id (int)
        
    '''
    prof_id = url.split('profid=')[-1]
    return int(prof_id)

# %% [markdown]
# # Start by Parsing Aggregate Data

# %%
def clean(words, letter_or_year=True, prof_id=0): 
    '''
    Cleans the Statistics from by Year and By Letter Grade
    
    Args: 
        words: (list): contains strings with the statistics inside.
        
        letter_or_year (bool): 
            True if parsing ratings by letter grades
            False if parsing ratings by year level
            
    Returns: 
        grades (dict): a dictionary of dictionaries that hold statistics. 
    
    '''
    
    grade_section = []
    
    if letter_or_year:
        for item in words: 
            #This is what we split on
            item = item.split('Receiving a Grade of \'')
            grade_section.append(item)
        
        
        grades = dict.fromkeys(['A', 'B', 'C', 'Credit','D', 'F', 'No Credit', 'N/A'])
       
    else: 
        for item in words: 
            #This is what we split on
            item = item.split('With a \'')
            grade_section.append(item)
            
        grades = dict.fromkeys(['Freshman', 'Sophomore', 'Junior', \
                                'Senior', '5th Year Senior', 'Graduate Student'])
        
    if len(grade_section) > 0:
        grade_section = grade_section[0] #The rest is negligible.

        #grade_section is now a list of strings
        for item in grade_section: 
            if letter_or_year:
                key=item[0]

                # We were only looking at the first character
                # We need the first 3 for N/A dict key
                if key == 'N':
                    if item[1] == 'o':
                        key = 'No Credit'
                    else:
                        key = 'N/A'

                if key == 'C' and item[1] == 'r':
                    key = 'Credit'

            else: 
                key = item.split('\' ')[0]

            if key in grades.keys(): 

                # Parse out the extra text strings. 
                # Only keep the ones with colons.
                start = 2
                end = 6
                stats = item.replace('\xa0', '').split('\n')[start: end]

                #Make a dict of each statistic and it's description
                d = dict(stat.split(":") for stat in stats)

                #Parse the types correctly
                for k in d.keys():
                    try:
                        d[k] = int(d[k])
                    except ValueError:
                        d[k] = float(d[k])

                #Assign the statistic dictionaries into the larger dictionary.
                grades[key] = d
    #             df.columns = df.columns.str.replace('Overall Grade','Overall Rating')
    else: 
        print('Professor ___ has nothing: ', prof_id)
    
    return grades #a dictionary of dictionaries

# %% [markdown]
# This function helps ensure that values are the correct type.

# %%
def parse_types(values):
    ''' Converts strings to floats or integers.
    Args: 
        list of strings
    Returns: 
        list containing floats and integers.
    '''
    
    parsed = []
    for value in values: 
        if '.' in value: 
            value = float(value)
        elif value == '': 
            value = 0
        else: 
            value = int(value)
        parsed.append(value)
        
    return parsed

# %% [markdown]
# # Scrape Statistics
# get_sample_stats extracts the mean, median, mode, and standard deviation for a professor on his/her full statistical analysis page. Here is an example page: http://polyratings.com/stats.phtml?profid=2073

# %%
def get_sample_stats(table_tag):
    
    '''
        Extracts mean, median, mode, and standard deviation for each professor. 
        
        Args: 
            table (td tag): holds tags within with data.
        
        Returns: 
            a DataFrame holding the statistics. 
    
    '''
    
    b_tags = table_tag.findAll('b')
    tds = []
    
    #Find td tags that follow b tags
    for b in b_tags: 
        tds.append(b.findNext('td'))
        
    #Just need the last four items.
    tds = tds[-4:]
    
    tds = [stat.text for stat in tds]
    
    stat_d = {}
    stat_d['mean'], stat_d['median'], stat_d['mode'], stat_d['std_dev'] = \
        parse_types(tds) 

    return pd.DataFrame.from_dict(data=stat_d, orient='index')

# %% [markdown]
# # Scrape Professor's Overall Statistics:
# ## * Overall rating
# ## * Ability to present material clearly
# ## * Ability to understand student difficulties

# %%
def get_prof_stats(full_stat_url):
    '''Returns a list of DataFrames of statistics scraped from a professor's
        full stat analysis url
    
        Args: 
            full_stat_url (string): the link to the professor's polyratings
        
        Returns:
            list 
            [prof_df (DataFrame): holds general info about professor
            prof_stats DataFrame]: holds statistics about professor
    
    '''
    
    prof_df = {}
    prof_stats = {}
    
    r = requests.get(full_stat_url)
    soup = BeautifulSoup(r.text, 'html.parser')
    
    # Professor Name and Department(s)
    fonts = soup.findAll('font') #each is type <class 'bs4.element.Tag'>
    name_font = fonts[2].text.replace('\n', ' ') 
    dept_font = fonts[3].text.replace('\n', ' ').split(' Department')[0]
    
    prof_df['Name'] = name_font
    prof_df['Dept'] = dept_font
    
    prof_id = get_prof_id(full_stat_url)
    prof_df['prof_id'] = prof_id
    
    # Professor Statistics
    stats = soup.findAll('table') 
    #we'll have to sort through different ones.
    # stats[2] is the name and dept table
    
    #Sections of HTML
    overall_t = stats[3]
    ability_to_present_t = stats[4]
    ability_to_understand_t = stats[5]
    #Total number of evaluations
    prof_df['Reporting Evaluations'] = int(overall_t.findAll('td', width='15%')[0].text)

    #Get Sample Stats for each table
    overall_sample_stats = get_sample_stats(overall_t)
    ability_to_present_sample_stats = get_sample_stats(ability_to_present_t)
    ability_to_understand_sample_stats = get_sample_stats(ability_to_understand_t)

    prof_stats = pd.merge(left=overall_sample_stats, \
                          right=ability_to_present_sample_stats, \
                         left_index=True, right_index=True, how='outer')
    prof_stats = pd.merge(left=prof_stats, right=ability_to_understand_sample_stats, \
                         left_index=True, right_index=True, how='outer')
    
    prof_stats = pd.DataFrame.transpose(prof_stats)
    prof_stats['rating_type'] = ['Overall Rating', 'Presents Material Clearly', \
                                 'Recognizes Student Difficulties']
    prof_stats['prof_id'] = prof_id
    prof_stats.index = ([0, 1, 2])
    
    prof_stats[['median', 'mode']] = prof_stats[['median', 'mode']].astype(int)
    prof_df = pd.DataFrame(prof_df, index=[0]).set_index(['prof_id'])

    # A list of dataframes that describe a professor
    return [prof_df, prof_stats]

# %% [markdown]
# # Scrape data from a full statistical analysis page including:
# ## * Overall statistics (by calling get_prof_stats),
# ## * Mean rating grouped by grade earned, and
# ## * Mean rating grouped by reviewers' year level.

# %%
def get_ratings(url):
    '''
    Calls functinos to get a list of DataFrames representing statistics for a professor. 
    
    Args: 
        url (string), the professor's statistical analysis page.
    Returns: 
        A list of DataFrames: 
         * prof_df: 
             the Professor DataFrame specifying name, number of evaluations, department
         * prof_stats:
             the Professor's Overall Rating Statistics
         * letter_grade_ratings:
             the Professor's Rating Statistics Based on Reviewer's Letter Grade Earned
         * year_grade_ratings:
             the Professor's Rating Statistics Based on Reviewer's Year Grade Earned
    
    '''
    
    prof_id = get_prof_id(url)
    print('\nProfessor: ', prof_id)
    
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    
    children = soup.getText().split('Polyratings.com')
    letter_grade_evals = children[3:4]
    year_grade_evals = children[4:5]
    
#     print("Letter_grade_evals in get_ratings()", letter_grade_evals)
    
    if len(letter_grade_evals) > 0:
    
        letter_grade_ratings = \
            pd.DataFrame(clean(letter_grade_evals, letter_or_year=True, prof_id=prof_id))
            
        letter_grade_ratings = \
            letter_grade_ratings.rename(index={'Overall Grade': 'Overall Rating'})
            
        letter_grade_ratings['prof_id'] = prof_id

        year_grade_ratings = \
            pd.DataFrame(clean(year_grade_evals, letter_or_year=False, prof_id=prof_id))
            
        year_grade_ratings = \
            year_grade_ratings.rename(index={'Overall Grade': 'Overall Rating'})
            
        year_grade_ratings['prof_id'] = prof_id

        #Get the mean, median, mode, std_dev of all ratings
        prof_df, prof_stats = get_prof_stats(url)

        return [prof_df, prof_stats, letter_grade_ratings, year_grade_ratings]
    else: 
        return ValueError()

# %% [markdown]
# # Collect Data on Each Professor
# ## * Convert professor page urls to professor full statistical analysis page urls.
# ## * Loop through and get_ratings on each professor.

# %%
def get_full_stat_urls(professor_paths): 
    '''Helper function, gets links to professors' full statistical analysis pages. 
        
       Args: 
           professor_paths (list of strings): 
               each is a link to a prof's polyratings page.
        
       Returns: 
           full_stat_paths (list of strings): each is a link to a prof's 
               full stat analysis page.
    '''
    
    # The trick is that the prof url might be: 
        # http://polyratings.com/eval.phtml?profid=2073
        
    # while the corresponding full stat analysis url is: 
        # http://polyratings.com/stats.phtml?profid=2073
        
    # Replace the word 'stats' with 'stats'
    
    return [p.replace('eval', 'stats') for p in professor_paths]


def get_all_professors_stats(professor_urls):

    '''Helper function: 
       Slowly collects data on each professor on polyratings.
       Calls parser functions to clean the data.
       
       Args: 
           professor_urls (list): links to professors' polyratings pages.
       Returns: 
           info from get_ratings(full_stat_url) for each professor
           all_prof_stats_dfs (list of lists of DataFrames)
               each item in list is a list containing 4 DataFrames
                    [[first_prof_df, 
                    first_prof_stats, 
                    first_prof_stats_by_letter, 
                    first_prof_stats_by_grade]
                    
                    [second_prof_df, 
                    second_prof_stats, 
                    second_prof_stats_by_letter, 
                    second_prof_stats_by_grade]
                    ...]
            
    '''
    full_stat_urls = get_full_stat_urls(professor_urls)
    all_prof_stats_dfs = []
    
    #Every so often, call data scraping functions on each url.
    for url in full_stat_urls:
        time.sleep(1.0)
        
        full_stat_url = url.replace('eval', 'stats')
        
        #Get the basic prof info as well as mean, median, mode, std_dev of all ratings
        all_prof_stats_dfs.append(get_ratings(full_stat_url))
        
    return all_prof_stats_dfs

# %% [markdown]
# ## Start by scraping a list of professor page urls.

# %%
professor_list_url = "http://polyratings.com/list.phtml"

def get_professor_urls():
    '''Gets links to professor polyratings pages. 
    
       Returns: 
           professor_paths (list of strings): each is a link.
    '''
    professor_list_url
    index = requests.get(professor_list_url)
    soup = BeautifulSoup(index.text, 'html.parser')
    professor_paths = []
    
    for a in soup.findAll('a'):
        if 'eval' in a['href']:
            professor_paths.append(a['href'])
      
    return professor_paths

# %% [markdown]
# ## Test the code with one professor:  Clint Staley

# %%
clint = 'http://polyratings.com/stats.phtml?profid=620'
clint_df, clint_stats, clint_stats_by_grade, clint_stats_by_year = get_ratings(clint)
# Out:
# Professor:  620

# %%
clint_df
# Out:
#                      Dept          Name  Reporting Evaluations
# prof_id
# 620      Computer Science  Clint Staley                    179

# %%
clint_stats
# Out:
#    median   mean  std_dev  mode                      rating_type  prof_id
# 0       0  3.034    1.410     4                   Overall Rating      620
# 1       0  3.251    1.272     4        Presents Material Clearly      620
# 2       0  2.872    1.446     4  Recognizes Student Difficulties      620

# %%
clint_stats_by_grade
# Out:
#                                       A       B       C Credit     D       F  \
# Overall Rating                    3.554   2.692   2.647   None  0.75   2.267
# Presents Material Clearly         3.717   2.974   3.059   None  1.50   2.200
# Recognizes Student Difficulties   3.435   2.692   2.294   None  0.25   2.000
# Reporting Evaluations            92.000  39.000  17.000   None  4.00  15.000
#
#                                     N/A  No Credit  prof_id
# Overall Rating                    2.364          3      620
# Presents Material Clearly         2.636          4      620
# Recognizes Student Difficulties   1.909          2      620
# Reporting Evaluations            11.000          1      620

# %%
print(clint_stats_by_grade['B'][0], type(clint_stats_by_grade['B'][0]))
assert type(clint_stats_by_grade['B'][0]) == np.float64
# Out:
# 2.692 <class 'numpy.float64'>

# %%
clint_stats_by_year
# Out:
#                                  5th Year Senior  Freshman  Graduate Student  \
# Overall Rating                             3.125      3.74             2.667
# Presents Material Clearly                  3.750      3.68             3.333
# Recognizes Student Difficulties            2.750      3.56             2.333
# Reporting Evaluations                      8.000     50.00             3.000
#
#                                  Junior  Senior  Sophomore  prof_id
# Overall Rating                    2.511   2.750      2.927      620
# Presents Material Clearly         2.894   3.063      3.145      620
# Recognizes Student Difficulties   2.426   2.375      2.818      620
# Reporting Evaluations            47.000  16.000     55.000      620

# %%
assert clint_stats_by_year['Freshman'][0] == 3.740

# %% [markdown]
# # Let's Try Two Professors!
# ### None values occur when Polyratings does not have data for those sections.

# %%
#Test first and last urls
professor_urls = get_professor_urls()[1:]
first = professor_urls[0] #first is a string
last = professor_urls[-1]
two_professors = [first, last]

# %%
assert first == 'http://polyratings.com/eval.phtml?profid=2073'
assert last == 'http://polyratings.com/eval.phtml?profid=728'

# %%
prof_dfs_list = get_all_professors_stats(two_professors)
# profs_dfs_list is a list of lists of dataframes. 

for i in prof_dfs_list: 
    print('\nAnother Professor\'s List of Data Frames: ', i[0]['Name'])
    for j in i:
        display(j)
    print('\n')
# Out:
# Professor:  2073
#
# Professor:  728
#
# Another Professor's List of Data Frames:  prof_id
# 2073    Christina Abel
# Name: Name, dtype: object
#                                Dept            Name  Reporting Evaluations
# prof_id
# 2073     Chemistry and Biochemistry  Christina Abel                     32
#    median   mean  std_dev  mode                      rating_type  prof_id
# 0       4  3.563    0.556     4                   Overall Rating     2073
# 1       4  3.594    0.551     4        Presents Material Clearly     2073
# 2       4  3.563    0.658     4  Recognizes Student Difficulties     2073
#                                       A      B     C Credit  D     F  N/A  \
# Overall Rating                    3.769  3.222  3.75   None  3  None    3
# Presents Material Clearly         3.769  3.222  3.75   None  3  None    4
# Recognizes Student Difficulties   3.692  3.222  3.75   None  4  None    3
# Reporting Evaluations            13.000  9.000  8.00   None  1  None    1
#
#                                 No Credit  prof_id
# Overall Rating                       None     2073
# Presents Material Clearly            None     2073
# Recognizes Student Difficulties      None     2073
# Reporting Evaluations                None     2073
#                                 5th Year Senior  Freshman Graduate Student  \
# Overall Rating                             None     3.500             None
# Presents Material Clearly                  None     3.714             None
# Recognizes Student Difficulties            None     3.571             None
# Reporting Evaluations                      None    14.000             None
#
#                                  Junior  Senior  Sophomore  prof_id
# Overall Rating                    4.000   3.333      3.583     2073
# Presents Material Clearly         3.667   3.333      3.500     2073
# Recognizes Student Difficulties   4.000   3.667      3.417     2073
# Reporting Evaluations             3.000   3.000     12.000     2073
# Another Professor's List of Data Frames:  prof_id
# 728    Dick Zweifel
# Name: Name, dtype: object
#                  Dept          Name  Reporting Evaluations
# prof_id
# 728      Architecture  Dick Zweifel                     16
#    median   mean  std_dev  mode                      rating_type  prof_id
# 0       1  1.625    1.317     1                   Overall Rating      728
# 1       2  2.375    1.111     2        Presents Material Clearly      728
# 2       2  1.875    1.166     1  Recognizes Student Difficulties      728
#                                     A     B     C  Credit     D  F    N/A  \
# Overall Rating                   None  None  None   1.083  None  4  3.000
# Presents Material Clearly        None  None  None   1.917  None  4  3.667
# Recognizes Student Difficulties  None  None  None   1.333  None  4  3.333
# Reporting Evaluations            None  None  None  12.000  None  1  3.000
#
#                                 No Credit  prof_id
# Overall Rating                       None      728
# Presents Material Clearly            None      728
# Recognizes Student Difficulties      None      728
# Reporting Evaluations                None      728
#                                  5th Year Senior  Freshman  Graduate Student  \
# Overall Rating                                 4     1.231                 4
# Presents Material Clearly                      4     2.154                 4
# Recognizes Student Difficulties                4     1.538                 4
# Reporting Evaluations                          1    13.000                 1
#
#                                  Junior Senior Sophomore  prof_id
# Overall Rating                        2   None      None      728
# Presents Material Clearly             2   None      None      728
# Recognizes Student Difficulties       2   None      None      728
# Reporting Evaluations                 1   None      None      728

# %%
this_professor = prof_dfs_list[0]
last_professor = prof_dfs_list[1]

#Test the first table
assert type(this_professor[0].index.values[0]) == np.int64
assert type(this_professor[0]['Dept'].values[0]) == str
assert type(this_professor[0]['Reporting Evaluations'].values[0]) == np.int64
assert type(this_professor[0]['Name'].values[0]) == str

#Test the second table
assert type(this_professor[1]['mode'].values[0]) == np.int64
assert type(this_professor[1]['median'].values[0]) == np.int64
assert type(this_professor[1]['mean'].values[0]) == np.float64
assert type(this_professor[1]['rating_type'].values[0]) == str
assert type(this_professor[1]['prof_id'].values[0]) == np.int64

#Test the third table
assert type(this_professor[2]['A'].values[0]) == np.float64
assert type(this_professor[2]['B'].values[0]) == np.float64
assert type(this_professor[2]['C'].values[0]) == np.float64
assert type(this_professor[2]['D'].values[0]) == np.float64
assert type(this_professor[2]['N/A'].values[0]) == np.float64
assert type(this_professor[2]['prof_id'].values[0]) == np.int64

#Test the fourth table
print(type(this_professor[3]['5th Year Senior'].values[0]))
assert type(last_professor[3]['5th Year Senior'].values[0]) == np.float64

assert type(this_professor[3]['Freshman'].values[0]) == np.float64
assert type(this_professor[3]['Sophomore'].values[0]) == np.float64
assert type(this_professor[3]['Junior'].values[0]) == np.float64
assert type(this_professor[3]['prof_id'].values[0]) == np.int64
# Out:
# <class 'NoneType'>

# %% [markdown]
# ## We Want 4 Total DataFrames that Hold This Info for All Professors
# ## -> Merge Each Professors' DataFrames Together
# ## -> The Professor Ids Identify unique professors in DataFrames

# %%
# Concatenate dataframes
def merge_professors(profs_dfs_list):
    
    '''
    Takes a list of professors' lists of DataFrames. 
    Joins each DataFrame into 
     Args: 
         profs_dfs_list (list of lists of DataFrames)
               each item in list is a list containing 4 DataFrames
            [[first_prof_df, first_prof_stats, 
            first_prof_stats_by_letter, 
            first_prof_stats_by_grade]
            [second_prof_df, second_prof_stats, 
            second_prof_stats_by_letter, 
            second_prof_stats_by_grade]
            ...]
            
    Returns:
        
        a list of 4 DataFrames with respective info for all professors. 
            
    
    '''
    
    iterprofs = iter(profs_dfs_list)
    
    first_prof = next(iterprofs)
    if type(first_prof[0]) == pd.DataFrame:
        profs_df = first_prof[0]
        print(profs_df)
    if type(first_prof[1]) == pd.DataFrame:
        profs_stats = first_prof[1]
        print(profs_stats)
    
    profs_stats_by_grade = first_prof[2]
    print(profs_stats_by_grade)
    
    profs_stats_by_year = first_prof[3]
    print(profs_stats_by_year)
    
    #Keep track of the profs_stats_by_letters without concatenating them.
    profs_stats_by_grade_list = [first_prof[2]]
    
    #Iterate through each professor
    for professor_list in iterprofs: 
        if type(professor_list) == list:
            profs_df = pd.concat([profs_df, professor_list[0]])
            profs_stats = pd.concat([profs_stats, \
                                     professor_list[1]]).reset_index(drop=True)
            
            profs_stats_by_letter = pd.concat([profs_stats_by_grade, \
                                               professor_list[2]])
            profs_stats_by_grade = pd.concat([profs_stats_by_year, \
                                              professor_list[3]], \
                                             join='outer', axis=0)
        
            profs_stats_by_grade_list.append(professor_list[2])

    return [profs_df, profs_stats, profs_stats_by_letter, \
            profs_stats_by_grade, profs_stats_by_grade_list]

# %% [markdown]
# ## Merged Professors' Data Frames

# %%
profs_df, profs_stats, profs_stats_by_grade, \
    profs_stats_by_year, profs_stats_by_grade_list = merge_professors(prof_dfs_list)
# Out:
#                                Dept            Name  Reporting Evaluations
# prof_id
# 2073     Chemistry and Biochemistry  Christina Abel                     32
#    median   mean  std_dev  mode                      rating_type  prof_id
# 0       4  3.563    0.556     4                   Overall Rating     2073
# 1       4  3.594    0.551     4        Presents Material Clearly     2073
# 2       4  3.563    0.658     4  Recognizes Student Difficulties     2073
#                                       A      B     C Credit  D     F  N/A  \
# Overall Rating                    3.769  3.222  3.75   None  3  None    3
# Presents Material Clearly         3.769  3.222  3.75   None  3  None    4
# Recognizes Student Difficulties   3.692  3.222  3.75   None  4  None    3
# Reporting Evaluations            13.000  9.000  8.00   None  1  None    1
#
#                                 No Credit  prof_id
# Overall Rating                       None     2073
# Presents Material Clearly            None     2073
# Recognizes Student Difficulties      None     2073
# Reporting Evaluations                None     2073
#                                 5th Year Senior  Freshman Graduate Student  \
# Overall Rating                             None     3.500             None
# Presents Material Clearly                  None     3.714             None
# Recognizes Student Difficulties            None     3.571             None
# Reporting Evaluations                      None    14.000             None
#
#                                  Junior  Senior  Sophomore  prof_id
# Overall Rating                    4.000   3.333      3.583     2073
# Presents Material Clearly         3.667   3.333      3.500     2073
# Recognizes Student Difficulties   4.000   3.667      3.417     2073
# Reporting Evaluations             3.000   3.000     12.000     2073

# %%
profs_df
# Out:
#                                Dept            Name  Reporting Evaluations
# prof_id
# 2073     Chemistry and Biochemistry  Christina Abel                     32
# 728                    Architecture    Dick Zweifel                     16

# %%
profs_stats
# Out:
#    median   mean  std_dev  mode                      rating_type  prof_id
# 0       4  3.563    0.556     4                   Overall Rating     2073
# 1       4  3.594    0.551     4        Presents Material Clearly     2073
# 2       4  3.563    0.658     4  Recognizes Student Difficulties     2073
# 3       1  1.625    1.317     1                   Overall Rating      728
# 4       2  2.375    1.111     2        Presents Material Clearly      728
# 5       2  1.875    1.166     1  Recognizes Student Difficulties      728

# %%
profs_stats_by_grade
# Out:
#                                       A      B     C  Credit   D   F    N/A  \
# Overall Rating                    3.769  3.222  3.75     NaN   3 NaN  3.000
# Presents Material Clearly         3.769  3.222  3.75     NaN   3 NaN  4.000
# Recognizes Student Difficulties   3.692  3.222  3.75     NaN   4 NaN  3.000
# Reporting Evaluations            13.000  9.000  8.00     NaN   1 NaN  1.000
# Overall Rating                      NaN    NaN   NaN   1.083 NaN   4  3.000
# Presents Material Clearly           NaN    NaN   NaN   1.917 NaN   4  3.667
# Recognizes Student Difficulties     NaN    NaN   NaN   1.333 NaN   4  3.333
# Reporting Evaluations               NaN    NaN   NaN  12.000 NaN   1  3.000
#
#                                 No Credit  prof_id
# Overall Rating                        NaN     2073
# Presents Material Clearly             NaN     2073
# Recognizes Student Difficulties       NaN     2073
# Reporting Evaluations                 NaN     2073
# Overall Rating                        NaN      728
# Presents Material Clearly             NaN      728
# Recognizes Student Difficulties       NaN      728
# Reporting Evaluations                 NaN      728

# %%
profs_stats_by_year
# Out:
#                                  5th Year Senior  Freshman  Graduate Student  \
# Overall Rating                               NaN     3.500               NaN
# Presents Material Clearly                    NaN     3.714               NaN
# Recognizes Student Difficulties              NaN     3.571               NaN
# Reporting Evaluations                        NaN    14.000               NaN
# Overall Rating                                 4     1.231                 4
# Presents Material Clearly                      4     2.154                 4
# Recognizes Student Difficulties                4     1.538                 4
# Reporting Evaluations                          1    13.000                 1
#
#                                  Junior  Senior  Sophomore  prof_id
# Overall Rating                    4.000   3.333      3.583     2073
# Presents Material Clearly         3.667   3.333      3.500     2073
# Recognizes Student Difficulties   4.000   3.667      3.417     2073
# Reporting Evaluations             3.000   3.000     12.000     2073
# Overall Rating                    2.000     NaN        NaN      728
# Presents Material Clearly         2.000     NaN        NaN      728
# Recognizes Student Difficulties   2.000     NaN        NaN      728
# Reporting Evaluations             1.000     NaN        NaN      728

# %%
profs_stats_by_grade_list[0:2]
# Out:
# [                                      A      B     C Credit  D     F  N/A  \
#  Overall Rating                    3.769  3.222  3.75   None  3  None    3
#  Presents Material Clearly         3.769  3.222  3.75   None  3  None    4
#  Recognizes Student Difficulties   3.692  3.222  3.75   None  4  None    3
#  Reporting Evaluations            13.000  9.000  8.00   None  1  None    1
#
#                                  No Credit  prof_id
#  Overall Rating                       None     2073
#  Presents Material Clearly            None     2073
#  Recognizes Student Difficulties      None     2073
#  Reporting Evaluations                None     2073  ,
#                                      A     B     C  Credit     D  F    N/A  \
#  Overall Rating                   None  None  None   1.083  None  4  3.000
#  Presents Material Clearly        None  None  None   1.917  None  4  3.667
#  Recognizes Student Difficulties  None  None  None   1.333  None  4  3.333
#  Reporting Evaluations            None  None  None  12.000  None  1  3.000
#
#                                  No Credit  prof_id
#  Overall Rating                       None      728
#  Presents Material Clearly            None      728
#  Recognizes Student Difficulties      None      728
#  Reporting Evaluations                None      728  ]

# %% [markdown]
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# # Scrape and Parse The Professors' Individual Reviews

# %%
def clean_review(review):
    '''
    Takes in a review bs4.element.Tag, which is a tr tag with review information
    Puts info into dictionaries, appended into a list.
    
    Args: 
        review (bs4.element.Tag): representing a tr tag.
    
    Returns:
        dictionaries (list): list of dictionaries.
    
    '''
    
    review_dict = {}
    
    #Parse the Review Id
    review_id_tag = review.findNext('a')
    review_id = int(str(review_id_tag).strip(' --></a>').split(' ')[-1])
    review_dict['review_id'] = review_id
    
    
    #Parse the Year and Grade of the student who wrote this review
    br_tags = review.find(['br'])
    years = str(br_tags).split('<br>')[1:3]
    
    #If there is year and grade info, parse it.
    if len(years) > 0:
        years = [x.strip('\n   ') for x in years]
        review_dict['Year'] = years[0]

        grade = years[1].rstrip('</b>').split(' <b>')
        review_dict['Grade'] = grade[1]
    
    #If there is a course name, parse it.
    review_year_tags = review.findAll(['b', 'a'])
    if len(review_year_tags) > 0:
        review_dict['Course'] = \
            str(review_year_tags[1]).rstrip('</a></b>').split('>')[-1]
        
        
    #Now parse the review 
    review_text = str(review).split('</td>')
    if len(review_text) > 1: 
        review_text = review_text[-2]
        
        if review_text.strip() != '<tr><td bgcolor="#ffffff" colspan="3">':
            review_text = \
                review_text.strip().lstrip('<td align="left" valign="top" \
                                            width="79%">').strip()
                
            review_dict['Review'] = review_text
    
    df =  pd.DataFrame.from_dict(review_dict, orient='index')
    
    return df.transpose()

def get_prof_reviews(page_url):
    
    '''
        Calls cleaner functions to tidy up reviews scraped from webpages.
        
        Args: 
            page_url (string): a link to professor's polyratings page.
            
        Returns: 
            reviews_df (DataFrame) a reviews DataFrame for that professor.
    
    '''
    
    r = requests.get(page_url)
    soup = BeautifulSoup(r.text, 'html.parser')
    prof_id = get_prof_id(page_url)
    
    table_rows = soup.findAll('tr')
    table_rows = table_rows
    
    reviews = []
    i = 0
    #clean up each row
    for row in table_rows[6:-3]:
        if i%2 == 0:
            row_df = clean_review(row)

            #if it's a review, add it to the review frame
            if len(row_df.columns) > 0: 
                reviews.append(row_df)
        i+=1 
    
    #connect review frames
    print('Professor Id: ', prof_id)
    if len(reviews) > 0:
        reviews_df = pd.concat(reviews)
        #tack on professor id.
        reviews_df['prof_id'] = prof_id
        
        return reviews_df
    else: 
        print('No reviews to concatenate.')


def get_all_profs_reviews(review_page_urls): 
    '''Helper function: 
       Slowly collects reviews on each professor on polyratings.
       Calls parser functions to clean the data.
       
       Args: 
           review_page_urls (list): links to professors' polyratings pages.
           
       Returns: 
           info from get_prof_reviews(page_url) for each professor
           reviews(list of lists of DataFrames)
               each item in list is a list containing 4 DataFrames
                    [[]
                    []
                    ...]
    '''

    professors_reviews = []
    
    #Every so often, call data scraping functions on each url.
    for url in review_page_urls:
        
        time.sleep(1.0)
        p_reviews = get_prof_reviews(url)
        if len(p_reviews) > 0:
            professors_reviews.append(p_reviews)
        
    return professors_reviews

# %% [markdown]
# ## Let's Test Getting Reviews for Just One Professor

# %%
from IPython.display import display

reviews = get_prof_reviews(two_professors[0]).reset_index(drop=True)

assert type(reviews['Grade'].values[0]) == str
assert type(reviews['Course'].values[0]) == str
assert type(reviews['Year'].values[0]) == str
assert type(reviews['Review'].values[0]) == str
assert type(reviews['review_id'].values[0]) == int
assert type(reviews['prof_id'].values[0]) == np.int64

reviews.head()
# Out:
# Professor Id:  2073
#                                               Review Grade review_id  \
# 0                                    anytext or 1=1'     B     54423
# 1  Abel is a pretty good chem teacher.  Her notes...     B     35061
# 2  Dr. Abel, is very helpful and approachable in ...     C     34766
# 3  Talks nonstop for 3/4 of the class period and ...     B     34495
# 4  To do well in Abel's class, the key is practic...     A     34359
#
#      Course      Year  prof_id
# 0  CHEM 111    Junior     2073
# 1  CHEM 125  Freshman     2073
# 2  CHEM 125    Senior     2073
# 3  CHEM 124  Freshman     2073
# 4  CHEM 124  Freshman     2073

# %% [markdown]
# ## Tack on the Overall Professor Ratings by Student Reviewer's Letter Grade Earned

# %%
def concat_prof_by_letter(prof_stats_by_letter, my_reviews):
    
    '''
    Adds the professor's overall ratings to each row, 
    depending on the grade earned by that review.
    
    Keeping all of this code in one function eliminates 
    the alternative predicament of passing many parameters 
    to a small functions.
    
    Args: 
        prof_stats_by_letter (DataFrame): 
            Shows the overall ratings for that professor as rated by the 
            groups of students, segregated by grade earned.
        
        my_reviews (DataFrame):
            DataFrame of reviews for the professor. 
    Returns: 
        A ratings DataFrame with all reviews for a professor and overall ratings. 
    
    
    '''
    A_reviews = pd.DataFrame(my_reviews[my_reviews.Grade == 'A'])
    A_reviews['Presents Material Clearly'] = \
        prof_stats_by_letter['A']['Presents Material Clearly']
        
    A_reviews['Overall Rating'] = prof_stats_by_letter['A']['Overall Rating']
    A_reviews['Recognizes Student Difficulties'] = \
        prof_stats_by_letter['A']['Recognizes Student Difficulties']
        
    A_reviews['Reporting Evaluations'] = \
        prof_stats_by_letter['A']['Reporting Evaluations']

    B_reviews = pd.DataFrame(my_reviews[my_reviews.Grade == 'B'])
    B_reviews['Presents Material Clearly'] = \
        prof_stats_by_letter['B']['Presents Material Clearly']
    B_reviews['Overall Rating'] = prof_stats_by_letter['B']['Overall Rating']
    B_reviews['Recognizes Student Difficulties'] = \
        prof_stats_by_letter['B']['Recognizes Student Difficulties']
    B_reviews['Reporting Evaluations'] = \
        prof_stats_by_letter['B']['Reporting Evaluations']

    C_reviews = pd.DataFrame(my_reviews[my_reviews.Grade == 'C'])
    C_reviews['Presents Material Clearly'] = \
        prof_stats_by_letter['C']['Presents Material Clearly']
    C_reviews['Overall Rating'] = prof_stats_by_letter['C']['Overall Rating']
    C_reviews['Recognizes Student Difficulties'] = \
        prof_stats_by_letter['C']['Recognizes Student Difficulties']
    C_reviews['Reporting Evaluations'] = \
        prof_stats_by_letter['C']['Reporting Evaluations']

    D_reviews = pd.DataFrame(my_reviews[my_reviews.Grade == 'D'])
    D_reviews['Presents Material Clearly'] = \
        prof_stats_by_letter['D']['Presents Material Clearly']
    D_reviews['Overall Rating'] = prof_stats_by_letter['D']['Overall Rating']
    D_reviews['Recognizes Student Difficulties'] = \
        prof_stats_by_letter['D']['Recognizes Student Difficulties']
    D_reviews['Reporting Evaluations'] = \
        prof_stats_by_letter['D']['Reporting Evaluations']

    F_reviews = pd.DataFrame(my_reviews[my_reviews.Grade == 'F'])
    F_reviews['Presents Material Clearly'] = \
        prof_stats_by_letter['F']['Presents Material Clearly']
    F_reviews['Overall Rating'] = prof_stats_by_letter['F']['Overall Rating']
    F_reviews['Recognizes Student Difficulties'] = \
        prof_stats_by_letter['F']['Recognizes Student Difficulties']
    F_reviews['Reporting Evaluations'] = \
        prof_stats_by_letter['F']['Reporting Evaluations']

    NA_reviews = pd.DataFrame(my_reviews[my_reviews.Grade == 'N/A'])
    NA_reviews['Presents Material Clearly'] = \
        prof_stats_by_letter['N/A']['Presents Material Clearly']
    NA_reviews['Overall Rating'] = prof_stats_by_letter['N/A']['Overall Rating']
    NA_reviews['Recognizes Student Difficulties'] = \
        prof_stats_by_letter['N/A']['Recognizes Student Difficulties']
    NA_reviews['Reporting Evaluations'] = \
        prof_stats_by_letter['N/A']['Reporting Evaluations']

    NoCredit_reviews = pd.DataFrame(my_reviews[my_reviews.Grade == 'No Credit'])
    NoCredit_reviews['Presents Material Clearly'] = \
        prof_stats_by_letter['No Credit']['Presents Material Clearly']
    NoCredit_reviews['Overall Rating'] = \
        prof_stats_by_letter['No Credit']['Overall Rating']
    NoCredit_reviews['Recognizes Student Difficulties'] = \
        prof_stats_by_letter['No Credit']['Recognizes Student Difficulties']
    NoCredit_reviews['Reporting Evaluations'] = \
        prof_stats_by_letter['No Credit']['Reporting Evaluations']
  
    Credit_reviews = pd.DataFrame(my_reviews[my_reviews.Grade == 'Credit'])
    Credit_reviews['Presents Material Clearly'] = \
        prof_stats_by_letter['Credit']['Presents Material Clearly']
    Credit_reviews['Overall Rating'] = \
        prof_stats_by_letter['Credit']['Overall Rating']
    Credit_reviews['Recognizes Student Difficulties'] = \
        prof_stats_by_letter['Credit']['Recognizes Student Difficulties']
    Credit_reviews['Reporting Evaluations'] = \
        prof_stats_by_letter['Credit']['Reporting Evaluations']

    assert type(A_reviews) == pd.DataFrame
    assert type(B_reviews) == pd.DataFrame
    assert type(C_reviews) == pd.DataFrame
    assert type(D_reviews) == pd.DataFrame
    assert type(F_reviews) == pd.DataFrame
    assert type(Credit_reviews) == pd.DataFrame
    assert type(NA_reviews) == pd.DataFrame
    assert type(NoCredit_reviews) == pd.DataFrame

    dataframes = []
    if len(A_reviews) > 0: 
        dataframes.append(A_reviews)
    if len(A_reviews) > 0: 
        dataframes.append(B_reviews)
    if len(A_reviews) > 0: 
        dataframes.append(C_reviews)
    if len(A_reviews) > 0: 
        dataframes.append(D_reviews)
    if len(A_reviews) > 0: 
        dataframes.append(F_reviews)
    if len(A_reviews) > 0: 
        dataframes.append(NA_reviews)
    if len(A_reviews) > 0: 
        dataframes.append(Credit_reviews)
    if len(A_reviews) > 0: 
        dataframes.append(NoCredit_reviews)
    if len(dataframes) > 0:
        return pd.concat(dataframes)
    else:
        return np.nan

# %%
def get_reviews_by_grade(professor_reviews, profs_stats_by_letter_list):
    '''
        Gets a Reviews DataFrame with Overall Professor Ratings 
        by Letter Grade, for all Professors.
        
        Args: 
            professor_reviews (list of DataFrames): 
                Each in the list holds ratings for a professor.
                
            profs_stats_by_letter_list (list of DataFrames):
                Each in the list holds mean ratings for a professor 
                based on Letter Grade earned by reviewer.
                
        Returns: 
            A Reviews DataFrame, indexed by review_ids, 
            showing Professors Overall Ratings based on 
            Grades, Grades, Year, Course, Prof_id, etc
    '''
    
    concatenateds = []
    n = len(profs_stats_by_letter_list)
    
    if n == len(professor_reviews):
        print('n = ', n)
        for letter_df, rev_df in zip(profs_stats_by_letter_list, professor_reviews):
            return_val = concat_prof_by_letter(letter_df, rev_df)
            if return_val is not np.nan:
                concatenateds.append(return_val)
        return pd.concat(concatenateds).reset_index(drop=True).set_index('review_id')
    else: 
        print('Lengths of lists of DataFrames are not compatible.')

# %% [markdown]
# ## Get Reviews Table For All Professors
# ## Set the Index to the Review_Id

# %%
my_reviews = get_all_profs_reviews(two_professors)
reviews_by_grade = get_reviews_by_grade(my_reviews, profs_stats_by_grade_list)
reviews_by_grade
# Out:
# Professor Id:  2073
# Professor Id:  728
# n =  2
#                                                       Review Grade    Course  \
# review_id
# 34359      To do well in Abel's class, the key is practic...     A  CHEM 124
# 34176      Great professor! I learned a lot in her class....     A  CHEM 127
# 34130                                                   good     A  CHEM 124
# 34073                                                  Foxy.     A  CHEM 125
# 34023      Abel is an amazing teacher.  I think anyone sh...     A  CHEM 124
# 33755      Dr. Abel is a fantastic teacher. She presents ...     A  CHEM 124
# 33725                                             Excellent.     A  CHEM 125
# 33448      SMOKING HOT.  Great teacher too.  No Hw.  Just...     A  CHEM 125
# 33145      She's a great teacher, seems real nervous at f...     A  CHEM 127
# 31992      Abel is amazing. She is really good at realizi...     A  CHEM 124
# 31660      Dr. Abel is a great chem prof. I would recomme...     A  CHEM 124
# 30100      Abel's class is doable but very tedious. Her t...     A  CHEM 127
# 29539      She is an excellent professor.  She really pre...     A  CHEM 125
# 54423                                        anytext or 1=1'     B  CHEM 111
# 35061      Abel is a pretty good chem teacher.  Her notes...     B  CHEM 125
# 34495      Talks nonstop for 3/4 of the class period and ...     B  CHEM 124
# 33034      an amazing professor. her worksheets really he...     B  CHEM 124
# 31798      Abel is ok. She makes some mistakes during lec...     B  CHEM 127
# 31425      She acts nervous, and like the comment before ...     B  CHEM 124
# 30204      Good prof, really nice.  Helpful during office...     B  CHEM 124
# 29886      I had Dr. Abel a year ago as a freshman, but P...     B  CHEM 124
# 29666      Everything for this class was straightforward....     B  CHEM 125
# 34766      Dr. Abel, is very helpful and approachable in ...     C  CHEM 125
# 34305      She's a great teacher, I found the 3 midterms ...     C  CHEM 124
# 33750      Dr. Abel is extremely helpful at recognizing s...     C  CHEM 124
# 33517      Professor Abel is an amazing teacher. She know...     C  CHEM 125
# 33108      I took Professor Abel my first quarter as a fr...     C  CHEM 127
# 32537      she is amazing. i nv have appreciated a teache...     C  CHEM 127
# 31366      Christina was a pretty good teacher and I enjo...     C  CHEM 124
# 30068      Abel is amazing! Presents the material clearly...     C  CHEM 127
# 33907      I could've done better in this class but I jus...     D  CHEM 127
# 31795                great. and very nice. very approachable   N/A  CHEM 127
#
#                 Year  prof_id  Presents Material Clearly  Overall Rating  \
# review_id
# 34359       Freshman     2073                      3.769           3.769
# 34176       Freshman     2073                      3.769           3.769
# 34130         Senior     2073                      3.769           3.769
# 34073      Sophomore     2073                      3.769           3.769
# 34023      Sophomore     2073                      3.769           3.769
# 33755       Freshman     2073                      3.769           3.769
# 33725      Sophomore     2073                      3.769           3.769
# 33448         Junior     2073                      3.769           3.769
# 33145      Sophomore     2073                      3.769           3.769
# 31992       Freshman     2073                      3.769           3.769
# 31660       Freshman     2073                      3.769           3.769
# 30100      Sophomore     2073                      3.769           3.769
# 29539       Freshman     2073                      3.769           3.769
# 54423         Junior     2073                      3.222           3.222
# 35061       Freshman     2073                      3.222           3.222
# 34495       Freshman     2073                      3.222           3.222
# 33034       Freshman     2073                      3.222           3.222
# 31798      Sophomore     2073                      3.222           3.222
# 31425         Senior     2073                      3.222           3.222
# 30204      Sophomore     2073                      3.222           3.222
# 29886       Freshman     2073                      3.222           3.222
# 29666      Sophomore     2073                      3.222           3.222
# 34766         Senior     2073                      3.750           3.750
# 34305       Freshman     2073                      3.750           3.750
# 33750         Junior     2073                      3.750           3.750
# 33517      Sophomore     2073                      3.750           3.750
# 33108      Sophomore     2073                      3.750           3.750
# 32537      Sophomore     2073                      3.750           3.750
# 31366       Freshman     2073                      3.750           3.750
# 30068       Freshman     2073                      3.750           3.750
# 33907       Freshman     2073                      3.000           3.000
# 31795      Sophomore     2073                      4.000           3.000
#
#            Recognizes Student Difficulties  Reporting Evaluations
# review_id
# 34359                                3.692                     13
# 34176                                3.692                     13
# 34130                                3.692                     13
# 34073                                3.692                     13
# 34023                                3.692                     13
# 33755                                3.692                     13
# 33725                                3.692                     13
# 33448                                3.692                     13
# 33145                                3.692                     13
# 31992                                3.692                     13
# 31660                                3.692                     13
# 30100                                3.692                     13
# 29539                                3.692                     13
# 54423                                3.222                      9
# 35061                                3.222                      9
# 34495                                3.222                      9
# 33034                                3.222                      9
# 31798                                3.222                      9
# 31425                                3.222                      9
# 30204                                3.222                      9
# 29886                                3.222                      9
# 29666                                3.222                      9
# 34766                                3.750                      8
# 34305                                3.750                      8
# 33750                                3.750                      8
# 33517                                3.750                      8
# 33108                                3.750                      8
# 32537                                3.750                      8
# 31366                                3.750                      8
# 30068                                3.750                      8
# 33907                                4.000                      1
# 31795                                3.000                      1

# %% [markdown]
# ## Use the Index to the Review_Id to Access Reviews

# %%
#You can do this for each dataframe in the list my_reviews

reviews_by_grade.loc[35061]
# Out:
# Review                             Abel is a pretty good chem teacher.  Her notes...
# Grade                                                                              B
# Course                                                                      CHEM 125
# Year                                                                        Freshman
# prof_id                                                                         2073
# Presents Material Clearly                                                      3.222
# Overall Rating                                                                 3.222
# Recognizes Student Difficulties                                                3.222
# Reporting Evaluations                                                              9
# Name: 35061, dtype: object

# %%
reviews_by_grade.loc[35061]['Review']
# Out:
# "Abel is a pretty good chem teacher.  Her notes are extremely well organized so it's really easy to go back and study before exams.  Unfortunately her class was at 7AM which may be why I found it boring.  Really nice, and super helpful.  Her tests are challenging but not impossible and you can get an A if you study for them.  DO THE WORKBOOKS, a lot of the problems and questions on her exams come straight out of the workbooks.  Also, she likes to give our a lot of supplemental handouts to go with her notes, STAPLE them to the corresponding page in your notes.  They are really helpful for your labs and quizzes but they are also really easy to lose or get mixed up."

# %% [markdown]
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# # Which DataFrames should we write to a JSON?
# profs_df, profs_stats, profs_stats_by_grade, profs_stats_by_year, profs_stats_by_letter_list = merge_professors(prof_dfs_list)
#
# Let's include the following:
# * profs_df
#     Basic Professor info (name, dept, #reviews)
# * profs_stats
#     Rating Averages, Standard Deviations, Median, Means per professor id.
# * profs_stats_by_grade_list
#     list of prof_stats_by_grade DataFrames, rather than a concatenated DataFrame
# * reviews_by_grade
#     profs_stats_by_grade per review id, well organized.
#
# Leave out:
# * profs_stats_by_year
#     Overall ratings for professors based on year level of reviewer
#
# * profs_stats_by_grade
#     Rating Averages per reviewer's earned grade per review id

# %% [markdown]
# #### profs_df json

# %%
profs_df
# Out:
#                                Dept            Name  Reporting Evaluations
# prof_id
# 2073     Chemistry and Biochemistry  Christina Abel                     32
# 728                    Architecture    Dick Zweifel                     16

# %%
p_df_json = profs_df.reset_index().to_json(orient='index') #don't drop index

# %%
pd.read_json(p_df_json).transpose()
# Out:
#                          Dept            Name Reporting Evaluations prof_id
# 0  Chemistry and Biochemistry  Christina Abel                    32    2073
# 1                Architecture    Dick Zweifel                    16     728

# %% [markdown]
# #### profs_stats json

# %%
profs_stats
# Out:
#    median   mean  std_dev  mode                      rating_type  prof_id
# 0       4  3.563    0.556     4                   Overall Rating     2073
# 1       4  3.594    0.551     4        Presents Material Clearly     2073
# 2       4  3.563    0.658     4  Recognizes Student Difficulties     2073
# 3       1  1.625    1.317     1                   Overall Rating      728
# 4       2  2.375    1.111     2        Presents Material Clearly      728
# 5       2  1.875    1.166     1  Recognizes Student Difficulties      728

# %%
p_stats_json = profs_stats.reset_index(drop=True).to_json(orient='index') # drop index
p_stats_json
# Out:
# '{"0":{"median":4,"mean":3.563,"std_dev":0.556,"mode":4,"rating_type":"Overall Rating","prof_id":2073},"1":{"median":4,"mean":3.594,"std_dev":0.551,"mode":4,"rating_type":"Presents Material Clearly","prof_id":2073},"2":{"median":4,"mean":3.563,"std_dev":0.658,"mode":4,"rating_type":"Recognizes Student Difficulties","prof_id":2073},"3":{"median":1,"mean":1.625,"std_dev":1.317,"mode":1,"rating_type":"Overall Rating","prof_id":728},"4":{"median":2,"mean":2.375,"std_dev":1.111,"mode":2,"rating_type":"Presents Material Clearly","prof_id":728},"5":{"median":2,"mean":1.875,"std_dev":1.166,"mode":1,"rating_type":"Recognizes Student Difficulties","prof_id":728}}'

# %%
pd.read_json(p_stats_json).transpose()
# Out:
#     mean median mode prof_id                      rating_type std_dev
# 0  3.563      4    4    2073                   Overall Rating   0.556
# 1  3.594      4    4    2073        Presents Material Clearly   0.551
# 2  3.563      4    4    2073  Recognizes Student Difficulties   0.658
# 3  1.625      1    1     728                   Overall Rating   1.317
# 4  2.375      2    2     728        Presents Material Clearly   1.111
# 5  1.875      2    1     728  Recognizes Student Difficulties   1.166

# %%
p_stats_by_grade_list_json = [df.to_json(orient='index') for df in profs_stats_by_grade_list]
p_stats_by_grade_list_json
# Out:
# ['{"Overall Rating":{"A":3.769,"B":3.222,"C":3.75,"Credit":null,"D":3.0,"F":null,"N\\/A":3.0,"No Credit":null,"prof_id":2073},"Presents Material Clearly":{"A":3.769,"B":3.222,"C":3.75,"Credit":null,"D":3.0,"F":null,"N\\/A":4.0,"No Credit":null,"prof_id":2073},"Recognizes Student Difficulties":{"A":3.692,"B":3.222,"C":3.75,"Credit":null,"D":4.0,"F":null,"N\\/A":3.0,"No Credit":null,"prof_id":2073},"Reporting Evaluations":{"A":13.0,"B":9.0,"C":8.0,"Credit":null,"D":1.0,"F":null,"N\\/A":1.0,"No Credit":null,"prof_id":2073}}',
#  '{"Overall Rating":{"A":null,"B":null,"C":null,"Credit":1.083,"D":null,"F":4.0,"N\\/A":3.0,"No Credit":null,"prof_id":728},"Presents Material Clearly":{"A":null,"B":null,"C":null,"Credit":1.917,"D":null,"F":4.0,"N\\/A":3.667,"No Credit":null,"prof_id":728},"Recognizes Student Difficulties":{"A":null,"B":null,"C":null,"Credit":1.333,"D":null,"F":4.0,"N\\/A":3.333,"No Credit":null,"prof_id":728},"Reporting Evaluations":{"A":null,"B":null,"C":null,"Credit":12.0,"D":null,"F":1.0,"N\\/A":3.0,"No Credit":null,"prof_id":728}}']

# %%
stats_by_grade = []
for df_json in p_stats_by_grade_list_json: 
    stats_by_grade.append(pd.read_json(df_json).transpose())
stats_by_grade[0].transpose()
# Out:
#            Overall Rating  Presents Material Clearly  \
# A                   3.769                      3.769
# B                   3.222                      3.222
# C                   3.750                      3.750
# Credit                NaN                        NaN
# D                   3.000                      3.000
# F                     NaN                        NaN
# N/A                 3.000                      4.000
# No Credit             NaN                        NaN
# prof_id          2073.000                   2073.000
#
#            Recognizes Student Difficulties  Reporting Evaluations
# A                                    3.692                     13
# B                                    3.222                      9
# C                                    3.750                      8
# Credit                                 NaN                    NaN
# D                                    4.000                      1
# F                                      NaN                    NaN
# N/A                                  3.000                      1
# No Credit                              NaN                    NaN
# prof_id                           2073.000                   2073

# %%
reviews_by_grade_json = reviews_by_grade.reset_index().to_json(orient='index')

# %%
pd.read_json(reviews_by_grade_json).transpose().set_index('review_id').head()
# Out:
#              Course Grade Overall Rating Presents Material Clearly  \
# review_id
# 34359      CHEM 124     A          3.769                     3.769
# 34176      CHEM 127     A          3.769                     3.769
# 31660      CHEM 124     A          3.769                     3.769
# 30100      CHEM 127     A          3.769                     3.769
# 29539      CHEM 125     A          3.769                     3.769
#
#           Recognizes Student Difficulties Reporting Evaluations  \
# review_id
# 34359                               3.692                    13
# 34176                               3.692                    13
# 31660                               3.692                    13
# 30100                               3.692                    13
# 29539                               3.692                    13
#
#                                                       Review       Year  \
# review_id
# 34359      To do well in Abel's class, the key is practic...   Freshman
# 34176      Great professor! I learned a lot in her class....   Freshman
# 31660      Dr. Abel is a great chem prof. I would recomme...   Freshman
# 30100      Abel's class is doable but very tedious. Her t...  Sophomore
# 29539      She is an excellent professor.  She really pre...   Freshman
#
#           prof_id
# review_id
# 34359        2073
# 34176        2073
# 31660        2073
# 30100        2073
# 29539        2073

# %%
def create_jsons(path, data):
    '''
    Uses json to save Data Frames to the path specified.
    
    Args: 
        path (string): where the data will be stored.
    
    Returns: 
        None.
    
    '''
    
    profs_df, profs_stats, profs_stats_by_grade_list, reviews_by_grade = data
    
    #don't drop index
    p_df_json = profs_df.reset_index().to_json(orient='index') 
    
    # drop index
    p_stats_json = profs_stats.reset_index(drop=True).to_json(orient='index') 
    
    
    p_stats_by_grade_list_json = \
        [df.to_json(orient='index') for df in profs_stats_by_grade_list]
    reviews_by_grade_json = reviews_by_grade.reset_index().to_json(orient='index')
    
    #create a json array
    json_array = \
        [p_df_json, p_stats_json, p_stats_by_grade_list_json, reviews_by_grade_json]
    
    
    with open(path, 'w') as outfile:
        json.dump(json_array, outfile)
        
create_jsons('/data/primitiveDataType/small_data.json', \
             [profs_df, profs_stats, profs_stats_by_grade_list, reviews_by_grade])

# %% [markdown]
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# # Let's Run the code for Every Professor!
#
# # The code below consumes time and RAM.We must avoid overwhelming the polyratings site.In order to do this, there is a time stall between each call to scrape a professor details
#
# Get links to all of the professors.

# %%
'''Get links to all the professors.
   Call parsing methods. 
'''
# Drop the first link to get links only linking to a professor page. 
professor_urls = get_professor_urls()[1:]

# %% [markdown]
# Drop professor pages that are incompatible with the code.

# %%
good_professor_urls = [p for p in professor_urls if '=1628' not in p]
good_professor_urls = [p for p in good_professor_urls if '=359' not in p]
good_professor_urls = [p for p in good_professor_urls if '=717' not in p]
good_professor_urls = [p for p in good_professor_urls if '=468' not in p]
good_professor_urls = [p for p in good_professor_urls if '=509' not in p]

print([p for p in good_professor_urls if '=717' in p])
# Out:
# []

# %% [markdown]
# # TIME CONSUMING CODE
# The following code takes a good hour to run because it gathers all the data for each professor on polyratings.

# %%
#This code takes forever to run.
professor_frames = get_all_professors_stats(good_professor_urls)
# Out:
# Professor:  2073
#
# Professor:  2390
#
# Professor:  2429
#
# Professor:  1
#
# Professor:  2
#
# Professor:  746
#
# Professor:  3
#
# Professor:  1252
#
# Professor:  2819
#
# Professor:  1693
#
# Professor:  2236
#
# Professor:  1617
#
# Professor:  4
#
# Professor:  1007
#
# Professor:  5
#
# Professor:  3351
#
# Professor:  4126
#
# Professor:  6
#
# Professor:  908
#
# Professor:  1095
#
# Professor:  4008
#
# Professor:  4167
#
# Professor:  2950
#
# Professor:  1418
#
# Professor:  2375
#
# Professor:  990
#
# Professor:  1748
#
# Professor:  974
#
# Professor:  778
#
# Professor:  7
#
# Professor:  2797
#
# Professor:  3452
#
# Professor:  3894
#
# Professor:  2089
#
# Professor:  8
#
# Professor:  9
#
# Professor:  10
#
# Professor:  891
#
# Professor:  11
#
# Professor:  2820
#
# Professor:  1403
#
# Professor:  2374
#
# Professor:  3035
#
# Professor:  4050
#
# Professor:  12
#
# Professor:  13
#
# Professor:  3500
#
# Professor:  2712
#
# Professor:  2739
#
# Professor:  3126
#
# Professor:  1991
#
# Professor:  14
#
# Professor:  1646
#
# Professor:  4168
#
# Professor:  2126
#
# Professor:  964
#
# Professor:  4172
#
# Professor:  965
#
# Professor:  852
#
# Professor:  1035
#
# Professor:  1736
#
# Professor:  3608
#
# Professor:  777
#
# Professor:  15
#
# Professor:  4140
#
# Professor:  1534
#
# Professor:  4112
#
# Professor:  1457
#
# Professor:  1158
#
# Professor:  3442
#
# Professor:  1114
#
# Professor:  17
#
# Professor:  18
#
# Professor:  3538
#
# Professor:  19
#
# Professor:  3625
#
# Professor:  888
#
# Professor:  2944
#
# Professor:  20
#
# Professor:  1317
#
# Professor:  4004
#
# Professor:  21
#
# Professor:  2904
#
# Professor:  2146
#
# Professor:  3068
#
# Professor:  971
#
# Professor:  2953
#
# Professor:  2082
#
# Professor:  2141
#
# Professor:  22
#
# Professor:  940
#
# Professor:  999
#
# Professor:  1387
#
# Professor:  23
#
# Professor:  24
#
# Professor:  1551
#
# Professor:  2997
#
# Professor:  901
#
# Professor:  4121
#
# Professor:  25
#
# Professor:  3052
#
# Professor:  26
#
# Professor:  1092
#
# Professor:  4131
#
# Professor:  4225
#
# Professor:  4216
#
# Professor:  2150
#
# Professor:  1301
#
# Professor:  27
#
# Professor:  28
#
# Professor:  1694
#
# Professor:  3441
#
# Professor:  29
#
# Professor:  2742
#
# Professor:  2340
#
# Professor:  3986
#
# Professor:  30
#
# Professor:  2798
#
# Professor:  4122
#
# Professor:  3026
#
# Professor:  2902
#
# Professor:  4178
#
# Professor:  988
#
# Professor:  31
#
# Professor:  32
#
# Professor:  33
#
# Professor:  3966
#
# Professor:  34
#
# Professor:  2012
#
# Professor:  1427
#
# Professor:  1419
#
# Professor:  35
#
# Professor:  36
#
# Professor:  4156
#
# Professor:  877
#
# Professor:  1738
#
# Professor:  37
#
# Professor:  2993
#
# Professor:  38
#
# Professor:  4027
#
# Professor:  1141
#
# Professor:  2928
#
# Professor:  2883
#
# Professor:  1481
#
# Professor:  1868
#
# Professor:  39
#
# Professor:  4044
#
# Professor:  40
#
# Professor:  3011
#
# Professor:  3991
#
# Professor:  788
#
# Professor:  2916
#
# Professor:  1430
#
# Professor:  41
#
# Professor:  4174
#
# Professor:  2850
#
# Professor:  1296
#
# Professor:  42
#
# Professor:  43
#
# Professor:  3055
#
# Professor:  1364
#
# Professor:  44
#
# Professor:  45
#
# Professor:  47
#
# Professor:  48
#
# Professor:  49
#
# Professor:  3967
#
# Professor:  50
#
# Professor:  3218
#
# Professor:  2406
#
# Professor:  51
#
# Professor:  889
#
# Professor:  1812
#
# Professor:  1151
#
# Professor:  52
#
# Professor:  53
#
# Professor:  2097
#
# Professor:  3425
#
# Professor:  1063
#
# Professor:  3536
#
# Professor:  54
#
# Professor:  55
#
# Professor:  1064
#
# Professor:  2125
#
# Professor:  1340
#
# Professor:  1772
#
# Professor:  2718
#
# Professor:  1154
#
# Professor:  56
#
# Professor:  57
#
# Professor:  2462
#
# Professor:  58
#
# Professor:  2782
#
# Professor:  957
#
# Professor:  59
#
# Professor:  3019
#
# Professor:  4015
#
# Professor:  1269
#
# Professor:  60
#
# Professor:  61
#
# Professor:  2694
#
# Professor:  1044
#
# Professor:  2711
#
# Professor:  62
#
# Professor:  4144
#
# Professor:  63
#
# Professor:  2867
#
# Professor:  873
#
# Professor:  858
#
# Professor:  64
#
# Professor:  4120
#
# Professor:  1119
#
# Professor:  65
#
# Professor:  4221
#
# Professor:  2360
#
# Professor:  66
#
# Professor:  1315
#
# Professor:  3343
#
# Professor:  2948
#
# Professor:  67
#
# Professor:  68
#
# Professor:  2964
#
# Professor:  800
#
# Professor:  69
#
# Professor:  3819
#
# Professor:  913
#
# Professor:  4092
#
# Professor:  70
#
# Professor:  836
#
# Professor:  1710
#
# Professor:  1242
#
# Professor:  2907
#
# Professor:  3329
#
# Professor:  1070
#
# Professor:  3943
#
# Professor:  1330
#
# Professor:  3993
#
# Professor:  71
#
# Professor:  4183
#
# Professor:  72
#
# Professor:  73
#
# Professor:  1960
#
# Professor:  74
#
# Professor:  76
#
# Professor:  77
#
# Professor:  2910
#
# Professor:  75
#
# Professor:  1150
#
# Professor:  79
#
# Professor:  78
#
# Professor:  758
#
# Professor:  3947
#
# Professor:  80
#
# Professor:  3015
#
# Professor:  81
#
# Professor:  1776
#
# Professor:  82
#
# Professor:  2475
#
# Professor:  2974
#
# Professor:  1591
#
# Professor:  83
#
# Professor:  1556
#
# Professor:  2116
#
# Professor:  1461
#
# Professor:  84
#
# Professor:  796
#
# Professor:  1225
#
# Professor:  3913
#
# Professor:  3990
#
# Professor:  85
#
# Professor:  3299
#
# Professor:  3964
#
# Professor:  3903
#
# Professor:  1490
#
# Professor:  2454
#
# Professor:  3989
#
# Professor:  86
#
# Professor:  2515
#
# Professor:  1541
#
# Professor:  87
#
# Professor:  2817
#
# Professor:  88
#
# Professor:  3444
#
# Professor:  1181
#
# Professor:  2818
#
# Professor:  1742
#
# Professor:  2617
#
# Professor:  2682
#
# Professor:  89
#
# Professor:  2963
#
# Professor:  2922
#
# Professor:  2404
#
# Professor:  1745
#
# Professor:  3362
#
# Professor:  3451
#
# Professor:  4208
#
# Professor:  3066
#
# Professor:  2889
#
# Professor:  90
#
# Professor:  4170
#
# Professor:  2831
#
# Professor:  2728
#
# Professor:  747
#
# Professor:  1062
#
# Professor:  4185
#
# Professor:  91
#
# Professor:  3939
#
# Professor:  92
#
# Professor:  93
#
# Professor:  94
#
# Professor:  3985
#
# Professor:  2135
#
# Professor:  1624
#
# Professor:  1263
#
# Professor:  2759
#
# Professor:  3898
#
# Professor:  95
#
# Professor:  2720
#
# Professor:  96
#
# Professor:  1278
#
# Professor:  97
#
# Professor:  98
#
# Professor:  3979
#
# Professor:  99
#
# Professor:  100
#
# Professor:  1236
#
# Professor:  3496
#
# Professor:  101
#
# Professor:  1822
#
# Professor:  2459
#
# Professor:  1359
#
# Professor:  102
#
# Professor:  1341
#
# Professor:  2227
#
# Professor:  2367
#
# Professor:  2557
#
# Professor:  925
#
# Professor:  3959
#
# Professor:  2653
#
# Professor:  103
#
# Professor:  1176
#
# Professor:  2191
#
# Professor:  2777
#
# Professor:  3090
#
# Professor:  3515
#
# Professor:  104
#
# Professor:  105
#
# Professor:  106
#
# Professor:  4035
#
# Professor:  4034
#
# Professor:  1220
#
# Professor:  1540
#
# Professor:  1323
#
# Professor:  107
#
# Professor:  108
#
# Professor:  1408
#
# Professor:  1921
#
# Professor:  2658
#
# Professor:  2987
#
# Professor:  109
#
# Professor:  813
#
# Professor:  110
#
# Professor:  111
#
# Professor:  2250
#
# Professor:  4222
#
# Professor:  112
#
# Professor:  1896
#
# Professor:  114
#
# Professor:  113
#
# Professor:  1147
#
# Professor:  1379
#
# Professor:  1774
#
# Professor:  1347
#
# Professor:  2138
#
# Professor:  115
#
# Professor:  2155
#
# Professor:  1810
#
# Professor:  1021
#
# Professor:  116
#
# Professor:  2854
#
# Professor:  1570
#
# Professor:  4047
#
# Professor:  969
#
# Professor:  2348
#
# Professor:  2417
#
# Professor:  117
#
# Professor:  879
#
# Professor:  118
#
# Professor:  1860
#
# Professor:  1316
#
# Professor:  1747
#
# Professor:  1193
#
# Professor:  2870
#
# Professor:  828
#
# Professor:  119
#
# Professor:  1640
#
# Professor:  3928
#
# Professor:  120
#
# Professor:  1104
#
# Professor:  121
#
# Professor:  122
#
# Professor:  2859
#
# Professor:  123
#
# Professor:  4176
#
# Professor:  124
#
# Professor:  869
#
# Professor:  4101
#
# Professor:  4180
#
# Professor:  125
#
# Professor:  126
#
# Professor:  127
#
# Professor:  2527
#
# Professor:  2412
#
# Professor:  128
#
# Professor:  1194
#
# Professor:  129
#
# Professor:  1047
#
# Professor:  130
#
# Professor:  131
#
# Professor:  931
#
# Professor:  1767
#
# Professor:  132
#
# Professor:  1054
#
# Professor:  2734
#
# Professor:  2750
#
# Professor:  2054
#
# Professor:  3054
#
# Professor:  1172
#
# Professor:  133
#
# Professor:  134
#
# Professor:  2885
#
# Professor:  2144
#
# Professor:  1878
#
# Professor:  3048
#
# Professor:  135
#
# Professor:  950
#
# Professor:  1005
#
# Professor:  1717
#
# Professor:  1471
#
# Professor:  966
#
# Professor:  136
#
# Professor:  1011
#
# Professor:  2049
#
# Professor:  137
#
# Professor:  1739
#
# Professor:  139
#
# Professor:  955
#
# Professor:  140
#
# Professor:  141
#
# Professor:  1508
#
# Professor:  907
#
# Professor:  2796
#
# Professor:  2801
#
# Professor:  142
#
# Professor:  1122
#
# Professor:  143
#
# Professor:  4032
#
# Professor:  3322
#
# Professor:  4141
#
# Professor:  1177
#
# Professor:  144
#
# Professor:  145
#
# Professor:  146
#
# Professor:  147
#
# Professor:  148
#
# Professor:  2059
#
# Professor:  1013
#
# Professor:  1544
#
# Professor:  2812
#
# Professor:  2132
#
# Professor:  149
#
# Professor:  1155
#
# Professor:  3917
#
# Professor:  1293
#
# Professor:  150
#
# Professor:  3607
#
# Professor:  3968
#
# Professor:  151
#
# Professor:  865
#
# Professor:  152
#
# Professor:  982
#
# Professor:  1470
#
# Professor:  924
#
# Professor:  1249
#
# Professor:  846
#
# Professor:  1138
#
# Professor:  3211
#
# Professor:  3719
#
# Professor:  153
#
# Professor:  4143
#
# Professor:  2368
#
# Professor:  2371
#
# Professor:  4028
#
# Professor:  2152
#
# Professor:  4151
#
# Professor:  154
#
# Professor:  856
#
# Professor:  1421
#
# Professor:  155
#
# Professor:  1284
#
# Professor:  1462
#
# Professor:  1332
#
# Professor:  1635
#
# Professor:  156
#
# Professor:  157
#
# Professor:  1358
#
# Professor:  1778
#
# Professor:  1561
#
# Professor:  158
#
# Professor:  159
#
# Professor:  160
#
# Professor:  4137
#
# Professor:  1219
#
# Professor:  161
#
# Professor:  4048
#
# Professor:  3388
#
# Professor:  1598
#
# Professor:  3946
#
# Professor:  1487
#
# Professor:  2946
#
# Professor:  162
#
# Professor:  163
#
# Professor:  3418
#
# Professor:  164
#
# Professor:  165
#
# Professor:  2827
#
# Professor:  2792
#
# Professor:  166
#
# Professor:  4057
#
# Professor:  1370
#
# Professor:  1111
#
# Professor:  2257
#
# Professor:  167
#
# Professor:  3908
#
# Professor:  1362
#
# Professor:  2067
#
# Professor:  3084
#
# Professor:  2747
#
# Professor:  168
#
# Professor:  1075
#
# Professor:  169
#
# Professor:  170
#
# Professor:  4058
#
# Professor:  2055
#
# Professor:  1257
#
# Professor:  986
#
# Professor:  171
#
# Professor:  172
#
# Professor:  1719
#
# Professor:  1320
#
# Professor:  2635
#
# Professor:  2725
#
# Professor:  173
#
# Professor:  941
#
# Professor:  1484
#
# Professor:  3114
#
# Professor:  174
#
# Professor:  4003
#
# Professor:  2770
#
# Professor:  2221
#
# Professor:  976
#
# Professor:  2758
#
# Professor:  1852
#
# Professor:  2843
#
# Professor:  2835
#
# Professor:  175
#
# Professor:  3110
#
# Professor:  176
#
# Professor:  739
#
# Professor:  916
#
# Professor:  177
#
# Professor:  4163
#
# Professor:  178
#
# Professor:  179
#
# Professor:  180
#
# Professor:  4201
#
# Professor:  2133
#
# Professor:  1346
#
# Professor:  3953
#
# Professor:  3969
#
# Professor:  2321
#
# Professor:  181
#
# Professor:  1582
#
# Professor:  3028
#
# Professor:  3914
#
# Professor:  3978
#
# Professor:  2842
#
# Professor:  182
#
# Professor:  183
#
# Professor:  2722
#
# Professor:  3077
#
# Professor:  2153
#
# Professor:  1382
#
# Professor:  3044
#
# Professor:  184
#
# Professor:  4199
#
# Professor:  1363
#
# Professor:  2768
#
# Professor:  1012
#
# Professor:  1335
#
# Professor:  3010
#
# Professor:  185
#
# Professor:  2445
#
# Professor:  2598
#
# Professor:  4165
#
# Professor:  1162
#
# Professor:  1961
#
# Professor:  872
#
# Professor:  186
#
# Professor:  187
#
# Professor:  4124
#
# Professor:  188
#
# Professor:  189
#
# Professor:  3952
#
# Professor:  2310
#
# Professor:  190
#
# Professor:  3619
#
# Professor:  3365
#
# Professor:  757
#
# Professor:  3440
#
# Professor:  191
#
# Professor:  1096
#
# Professor:  3376
#
# Professor:  193
#
# Professor:  2888
#
# Professor:  3121
#
# Professor:  2450
#
# Professor:  2387
#
# Professor:  3378
#
# Professor:  4065
#
# Professor:  4074
#
# Professor:  2107
#
# Professor:  3408
#
# Professor:  194
#
# Professor:  1724
#
# Professor:  195
#
# Professor:  1597
#
# Professor:  782
#
# Professor:  196
#
# Professor:  1050
#
# Professor:  2289
#
# Professor:  2187
#
# Professor:  197
#
# Professor:  2223
#
# Professor:  1325
#
# Professor:  2432
#
# Professor:  198
#
# Professor:  3929
#
# Professor:  1509
#
# Professor:  1378
#
# Professor:  1377
#
# Professor:  199
#
# Professor:  201
#
# Professor:  3368
#
# Professor:  3369
#
# Professor:  202
#
# Professor:  1006
#
# Professor:  833
#
# Professor:  1843
#
# Professor:  2607
#
# Professor:  1807
#
# Professor:  203
#
# Professor:  204
#
# Professor:  1782
#
# Professor:  205
#
# Professor:  3061
#
# Professor:  3308
#
# Professor:  2752
#
# Professor:  206
#
# Professor:  1777
#
# Professor:  1831
#
# Professor:  207
#
# Professor:  1106
#
# Professor:  208
#
# Professor:  209
#
# Professor:  4160
#
# Professor:  3353
#
# Professor:  1828
#
# Professor:  765
#
# Professor:  210
#
# Professor:  842
#
# Professor:  3688
#
# Professor:  211
#
# Professor:  2075
#
# Professor:  212
#
# Professor:  213
#
# Professor:  2544
#
# Professor:  214
#
# Professor:  216
#
# Professor:  215
#
# Professor:  2091
#
# Professor:  217
#
# Professor:  896
#
# Professor:  1795
#
# Professor:  1689
#
# Professor:  3902
#
# Professor:  4060
#
# Professor:  218
#
# Professor:  1020
#
# Professor:  219
#
# Professor:  3911
#
# Professor:  2929
#
# Professor:  791
#
# Professor:  220
#
# Professor:  3162
#
# Professor:  221
#
# Professor:  1535
#
# Professor:  794
#
# Professor:  222
#
# Professor:  4147
#
# Professor:  2858
#
# Professor:  223
#
# Professor:  224
#
# Professor:  225
#
# Professor:  803
#
# Professor:  1051
#
# Professor:  2318
#
# Professor:  763
#
# Professor:  1089
#
# Professor:  1906
#
# Professor:  1904
#
# Professor:  1165
#
# Professor:  1928
#
# Professor:  226
#
# Professor:  787
#
# Professor:  2351
#
# Professor:  2419
#
# Professor:  1019
#
# Professor:  200
#
# Professor:  2159
#
# Professor:  933
#
# Professor:  2802
#
# Professor:  2978
#
# Professor:  3018
#
# Professor:  1033
#
# Professor:  1201
#
# Professor:  227
#
# Professor:  1871
#
# Professor:  228
#
# Professor:  229
#
# Professor:  2828
#
# Professor:  4049
#
# Professor:  3529
#
# Professor:  2927
#
# Professor:  946
#
# Professor:  1426
#
# Professor:  3934
#
# Professor:  1302
#
# Professor:  503
#
# Professor:  3386
#
# Professor:  2337
#
# Professor:  1931
#
# Professor:  230
#
# Professor:  231
#
# Professor:  3750
#
# Professor:  232
#
# Professor:  1763
#
# Professor:  1785
#
# Professor:  1014
#
# Professor:  233
#
# Professor:  234
#
# Professor:  235
#
# Professor:  236
#
# Professor:  3996
#
# Professor:  871
#
# Professor:  237
#
# Professor:  238
#
# Professor:  240
#
# Professor:  1398
#
# Professor:  241
#
# Professor:  242
#
# Professor:  960
#
# Professor:  1393
#
# Professor:  243
#
# Professor:  1412
#
# Professor:  244
#
# Professor:  1669
#
# Professor:  1329
#
# Professor:  1495
#
# Professor:  3025
#
# Professor:  3034
#
# Professor:  1216
#
# Professor:  245
#
# Professor:  1667
#
# Professor:  246
#
# Professor:  247
#
# Professor:  1732
#
# Professor:  3468
#
# Professor:  1127
#
# Professor:  2610
#
# Professor:  2147
#
# Professor:  998
#
# Professor:  248
#
# Professor:  249
#
# Professor:  1659
#
# Professor:  2683
#
# Professor:  250
#
# Professor:  1496
#
# Professor:  3511
#
# Professor:  1537
#
# Professor:  1605
#
# Professor:  4038
#
# Professor:  4011
#
# Professor:  1429
#
# Professor:  4227
#
# Professor:  251
#
# Professor:  2314
#
# Professor:  2064
#
# Professor:  252
#
# Professor:  2945
#
# Professor:  4207
#
# Professor:  3460
#
# Professor:  253
#
# Professor:  1800
#
# Professor:  818
#
# Professor:  254
#
# Professor:  802
#
# Professor:  1260
#
# Professor:  909
#
# Professor:  1130
#
# Professor:  255
#
# Professor:  1322
#
# Professor:  256
#
# Professor:  2094
#
# Professor:  2078
#
# Professor:  1839
#
# Professor:  1498
#
# Professor:  1876
#
# Professor:  4171
#
# Professor:  4113
#
# Professor:  257
#
# Professor:  4204
#
# Professor:  258
#
# Professor:  910
#
# Professor:  1314
#
# Professor:  2619
#
# Professor:  2721
#
# Professor:  2662
#
# Professor:  1737
#
# Professor:  1326
#
# Professor:  2932
#
# Professor:  827
#
# Professor:  1734
#
# Professor:  983
#
# Professor:  1112
#
# Professor:  259
#
# Professor:  3409
#
# Professor:  2803
#
# Professor:  1696
#
# Professor:  260
#
# Professor:  3039
#
# Professor:  261
#
# Professor:  1450
#
# Professor:  2134
#
# Professor:  262
#
# Professor:  1907
#
# Professor:  3071
#
# Professor:  263
#
# Professor:  3128
#
# Professor:  1626
#
# Professor:  264
#
# Professor:  2924
#
# Professor:  3884
#
# Professor:  2062
#
# Professor:  1762
#
# Professor:  1639
#
# Professor:  265
#
# Professor:  267
#
# Professor:  268
#
# Professor:  269
#
# Professor:  270
#
# Professor:  271
#
# Professor:  272
#
# Professor:  1031
#
# Professor:  4094
#
# Professor:  3030
#
# Professor:  273
#
# Professor:  274
#
# Professor:  1602
#
# Professor:  1410
#
# Professor:  3067
#
# Professor:  1422
#
# Professor:  2123
#
# Professor:  4006
#
# Professor:  1797
#
# Professor:  1239
#
# Professor:  275
#
# Professor:  276
#
# Professor:  1149
#
# Professor:  3944
#
# Professor:  2804
#
# Professor:  277
#
# Professor:  2332
#
# Professor:  278
#
# Professor:  4150
#
# Professor:  279
#
# Professor:  3950
#
# Professor:  1381
#
# Professor:  280
#
# Professor:  2881
#
# Professor:  1673
#
# Professor:  2869
#
# Professor:  923
#
# Professor:  1339
#
# Professor:  4072
#
# Professor:  1367
#
# Professor:  1142
#
# Professor:  282
#
# Professor:  2364
#
# Professor:  283
#
# Professor:  1486
#
# Professor:  1351
#
# Professor:  1232
#
# Professor:  895
#
# Professor:  2166
#
# Professor:  943
#
# Professor:  4020
#
# Professor:  2736
#
# Professor:  2762
#
# Professor:  2791
#
# Professor:  2786
#
# Professor:  886
#
# Professor:  2934
#
# Professor:  2118
#
# Professor:  284
#
# Professor:  285
#
# Professor:  1585
#
# Professor:  1723
#
# Professor:  1459
#
# Professor:  286
#
# Professor:  1607
#
# Professor:  3717
#
# Professor:  287
#
# Professor:  288
#
# Professor:  289
#
# Professor:  1191
#
# Professor:  2998
#
# Professor:  290
#
# Professor:  291
#
# Professor:  1665
#
# Professor:  1109
#
# Professor:  2346
#
# Professor:  292
#
# Professor:  2769
#
# Professor:  4067
#
# Professor:  293
#
# Professor:  294
#
# Professor:  3710
#
# Professor:  1791
#
# Professor:  930
#
# Professor:  2723
#
# Professor:  1108
#
# Professor:  295
#
# Professor:  2973
#
# Professor:  2485
#
# Professor:  1174
#
# Professor:  296
#
# Professor:  1342
#
# Professor:  2729
#
# Professor:  1365
#
# Professor:  297
#
# Professor:  2936
#
# Professor:  298
#
# Professor:  1525
#
# Professor:  3111
#
# Professor:  2951
#
# Professor:  299
#
# Professor:  300
#
# Professor:  301
#
# Professor:  2892
#
# Professor:  830
#
# Professor:  302
#
# Professor:  303
#
# Professor:  2158
#
# Professor:  762
#
# Professor:  3003
#
# Professor:  2601
#
# Professor:  2111
#
# Professor:  1243
#
# Professor:  3492
#
# Professor:  304
#
# Professor:  1873
#
# Professor:  1060
#
# Professor:  2620
#
# Professor:  305
#
# Professor:  1276
#
# Professor:  3083
#
# Professor:  306
#
# Professor:  4136
#
# Professor:  2131
#
# Professor:  307
#
# Professor:  1857
#
# Professor:  2053
#
# Professor:  308
#
# Professor:  309
#
# Professor:  4123
#
# Professor:  1389
#
# Professor:  310
#
# Professor:  3550
#
# Professor:  311
#
# Professor:  2358
#
# Professor:  3024
#
# Professor:  745
#
# Professor:  1533
#
# Professor:  3733
#
# Professor:  312
#
# Professor:  4149
#
# Professor:  2313
#
# Professor:  2316
#
# Professor:  2436
#
# Professor:  2701
#
# Professor:  3350
#
# Professor:  313
#
# Professor:  2335
#
# Professor:  314
#
# Professor:  1308
#
# Professor:  2807
#
# Professor:  2816
#
# Professor:  3674
#
# Professor:  2087
#
# Professor:  2809
#
# Professor:  315
#
# Professor:  1611
#
# Professor:  1170
#
# Professor:  2749
#
# Professor:  1156
#
# Professor:  1305
#
# Professor:  4021
#
# Professor:  316
#
# Professor:  317
#
# Professor:  1373
#
# Professor:  754
#
# Professor:  1511
#
# Professor:  1592
#
# Professor:  2379
#
# Professor:  2394
#
# Professor:  815
#
# Professor:  4091
#
# Professor:  755
#
# Professor:  3149
#
# Professor:  319
#
# Professor:  318
#
# Professor:  320
#
# Professor:  3254
#
# Professor:  2452
#
# Professor:  2440
#
# Professor:  1255
#
# Professor:  321
#
# Professor:  4129
#
# Professor:  3889
#
# Professor:  322
#
# Professor:  750
#
# Professor:  2756
#
# Professor:  1152
#
# Professor:  3342
#
# Professor:  325
#
# Professor:  324
#
# Professor:  323
#
# Professor:  3017
#
# Professor:  2129
#
# Professor:  1811
#
# Professor:  1657
#
# Professor:  326
#
# Professor:  1086
#
# Professor:  3963
#
# Professor:  2195
#
# Professor:  327
#
# Professor:  328
#
# Professor:  1121
#
# Professor:  1753
#
# Professor:  2872
#
# Professor:  867
#
# Professor:  1168
#
# Professor:  2930
#
# Professor:  329
#
# Professor:  330
#
# Professor:  820
#
# Professor:  1103
#
# Professor:  1261
#
# Professor:  331
#
# Professor:  2035
#
# Professor:  4026
#
# Professor:  332
#
# Professor:  4061
#
# Professor:  4203
#
# Professor:  3096
#
# Professor:  1287
#
# Professor:  333
#
# Professor:  1414
#
# Professor:  334
#
# Professor:  4152
#
# Professor:  335
#
# Professor:  2689
#
# Professor:  1010
#
# Professor:  336
#
# Professor:  337
#
# Professor:  2979
#
# Professor:  898
#
# Professor:  932
#
# Professor:  3909
#
# Professor:  2366
#
# Professor:  1265
#
# Professor:  934
#
# Professor:  338
#
# Professor:  2019
#
# Professor:  1559
#
# Professor:  1078
#
# Professor:  339
#
# Professor:  4215
#
# Professor:  1910
#
# Professor:  1682
#
# Professor:  2795
#
# Professor:  2949
#
# Professor:  1304
#
# Professor:  1024
#
# Professor:  1038
#
# Professor:  3079
#
# Professor:  2370
#
# Professor:  340
#
# Professor:  341
#
# Professor:  3101
#
# Professor:  2906
#
# Professor:  3394
#
# Professor:  2552
#
# Professor:  2027
#
# Professor:  2345
#
# Professor:  2781
#
# Professor:  342
#
# Professor:  2569
#
# Professor:  343
#
# Professor:  344
#
# Professor:  840
#
# Professor:  345
#
# Professor:  2826
#
# Professor:  2861
#
# Professor:  2137
#
# Professor:  956
#
# Professor:  899
#
# Professor:  1932
#
# Professor:  2913
#
# Professor:  841
#
# Professor:  346
#
# Professor:  347
#
# Professor:  1333
#
# Professor:  844
#
# Professor:  348
#
# Professor:  349
#
# Professor:  4109
#
# Professor:  350
#
# Professor:  3918
#
# Professor:  351
#
# Professor:  1779
#
# Professor:  352
#
# Professor:  2388
#
# Professor:  2142
#
# Professor:  4064
#
# Professor:  2990
#
# Professor:  3484
#
# Professor:  1192
#
# Professor:  2849
#
# Professor:  1515
#
# Professor:  353
#
# Professor:  1058
#
# Professor:  839
#
# Professor:  354
#
# Professor:  3927
#
# Professor:  1113
#
# Professor:  2937
#
# Professor:  963
#
# Professor:  355
#
# Professor:  4145
#
# Professor:  2163
#
# Professor:  3718
#
# Professor:  2395
#
# Professor:  1107
#
# Professor:  3885
#
# Professor:  1281
#
# Professor:  356
#
# Professor:  3924
#
# Professor:  1148
#
# Professor:  3038
#
# Professor:  1065
#
# Professor:  357
#
# Professor:  4154
#
# Professor:  2918
#
# Professor:  2995
#
# Professor:  4093
#
# Professor:  358
#
# Professor:  3056
#
# Professor:  1637
#
# Professor:  360
#
# Professor:  361
#
# Professor:  1695
#
# Professor:  2621
#
# Professor:  835
#
# Professor:  1067
#
# Professor:  362
#
# Professor:  2908
#
# Professor:  1655
#
# Professor:  4051
#
# Professor:  2917
#
# Professor:  1017
#
# Professor:  363
#
# Professor:  364
#
# Professor:  2790
#
# Professor:  2088
#
# Professor:  2899
#
# Professor:  365
#
# Professor:  2143
#
# Professor:  894
#
# Professor:  4090
#
# Professor:  3073
#
# Professor:  997
#
# Professor:  1756
#
# Professor:  366
#
# Professor:  1631
#
# Professor:  2377
#
# Professor:  4142
#
# Professor:  2160
#
# Professor:  3886
#
# Professor:  1008
#
# Professor:  2700
#
# Professor:  367
#
# Professor:  884
#
# Professor:  4005
#
# Professor:  1814
#
# Professor:  2128
#
# Professor:  2072
#
# Professor:  3033
#
# Professor:  3970
#
# Professor:  3013
#
# Professor:  1989
#
# Professor:  1789
#
# Professor:  368
#
# Professor:  2309
#
# Professor:  2411
#
# Professor:  1448
#
# Professor:  2863
#
# Professor:  912
#
# Professor:  369
#
# Professor:  370
#
# Professor:  371
#
# Professor:  372
#
# Professor:  1094
#
# Professor:  373
#
# Professor:  374
#
# Professor:  375
#
# Professor:  1286
#
# Professor:  376
#
# Professor:  1016
#
# Professor:  1266
#
# Professor:  2336
#
# Professor:  2939
#
# Professor:  2829
#
# Professor:  377
#
# Professor:  1402
#
# Professor:  1385
#
# Professor:  3517
#
# Professor:  2785
#
# Professor:  378
#
# Professor:  3459
#
# Professor:  3415
#
# Professor:  1066
#
# Professor:  379
#
# Professor:  3983
#
# Professor:  1443
#
# Professor:  380
#
# Professor:  1482
#
# Professor:  3047
#
# Professor:  4218
#
# Professor:  1169
#
# Professor:  1662
#
# Professor:  381
#
# Professor:  3736
#
# Professor:  2175
#
# Professor:  382
#
# Professor:  383
#
# Professor:  1823
#
# Professor:  2021
#
# Professor:  3735
#
# Professor:  384
#
# Professor:  385
#
# Professor:  386
#
# Professor:  387
#
# Professor:  1428
#
# Professor:  388
#
# Professor:  751
#
# Professor:  389
#
# Professor:  3443
#
# Professor:  2738
#
# Professor:  779
#
# Professor:  4194
#
# Professor:  2119
#
# Professor:  1750
#
# Professor:  951
#
# Professor:  2793
#
# Professor:  390
#
# Professor:  2882
#
# Professor:  392
#
# Professor:  391
#
# Professor:  979
#
# Professor:  393
#
# Professor:  394
#
# Professor:  981
#
# Professor:  395
#
# Professor:  4184
#
# Professor:  396
#
# Professor:  959
#
# Professor:  2373
#
# Professor:  397
#
# Professor:  398
#
# Professor:  3053
#
# Professor:  399
#
# Professor:  2719
#
# Professor:  1485
#
# Professor:  1504
#
# Professor:  3147
#
# Professor:  1004
#
# Professor:  2435
#
# Professor:  921
#
# Professor:  798
#
# Professor:  400
#
# Professor:  401
#
# Professor:  2308
#
# Professor:  402
#
# Professor:  1000
#
# Professor:  1368
#
# Professor:  1167
#
# Professor:  3389
#
# Professor:  4219
#
# Professor:  2543
#
# Professor:  2315
#
# Professor:  2430
#
# Professor:  2383
#
# Professor:  1153
#
# Professor:  904
#
# Professor:  3994
#
# Professor:  2066
#
# Professor:  403
#
# Professor:  3493
#
# Professor:  3091
#
# Professor:  2172
#
# Professor:  2554
#
# Professor:  3916
#
# Professor:  405
#
# Professor:  404
#
# Professor:  406
#
# Professor:  407
#
# Professor:  2378
#
# Professor:  970
#
# Professor:  408
#
# Professor:  4205
#
# Professor:  1025
#
# Professor:  3097
#
# Professor:  2938
#
# Professor:  2154
#
# Professor:  2733
#
# Professor:  409
#
# Professor:  2864
#
# Professor:  410
#
# Professor:  1124
#
# Professor:  1411
#
# Professor:  2080
#
# Professor:  3453
#
# Professor:  1500
#
# Professor:  2323
#
# Professor:  1855
#
# Professor:  1927
#
# Professor:  2799
#
# Professor:  903
#
# Professor:  2317
#
# Professor:  3907
#
# Professor:  411
#
# Professor:  412
#
# Professor:  1846
#
# Professor:  2541
#
# Professor:  1117
#
# Professor:  3383
#
# Professor:  737
#
# Professor:  4089
#
# Professor:  1618
#
# Professor:  413
#
# Professor:  414
#
# Professor:  4055
#
# Professor:  1850
#
# Professor:  415
#
# Professor:  416
#
# Professor:  987
#
# Professor:  1384
#
# Professor:  3510
#
# Professor:  3014
#
# Professor:  2773
#
# Professor:  1456
#
# Professor:  1343
#
# Professor:  418
#
# Professor:  417
#
# Professor:  419
#
# Professor:  1435
#
# Professor:  420
#
# Professor:  1356
#
# Professor:  2714
#
# Professor:  2874
#
# Professor:  421
#
# Professor:  422
#
# Professor:  2851
#
# Professor:  2853
#
# Professor:  423
#
# Professor:  2092
#
# Professor:  4031
#
# Professor:  752
#
# Professor:  424
#
# Professor:  1277
#
# Professor:  425
#
# Professor:  3888
#
# Professor:  426
#
# Professor:  427
#
# Professor:  428
#
# Professor:  890
#
# Professor:  1061
#
# Professor:  3020
#
# Professor:  1530
#
# Professor:  3501
#
# Professor:  430
#
# Professor:  4041
#
# Professor:  431
#
# Professor:  1676
#
# Professor:  2438
#
# Professor:  2376
#
# Professor:  2384
#
# Professor:  432
#
# Professor:  1069
#
# Professor:  4036
#
# Professor:  1292
#
# Professor:  3087
#
# Professor:  1439
#
# Professor:  1749
#
# Professor:  4056
#
# Professor:  433
#
# Professor:  1521
#
# Professor:  1336
#
# Professor:  434
#
# Professor:  435
#
# Professor:  436
#
# Professor:  437
#
# Professor:  1140
#
# Professor:  1449
#
# Professor:  1057
#
# Professor:  438
#
# Professor:  439
#
# Professor:  2148
#
# Professor:  1488
#
# Professor:  440
#
# Professor:  892
#
# Professor:  4083
#
# Professor:  2074
#
# Professor:  3088
#
# Professor:  3164
#
# Professor:  2329
#
# Professor:  2415
#
# Professor:  1472
#
# Professor:  441
#
# Professor:  4040
#
# Professor:  3051
#
# Professor:  4187
#
# Professor:  442
#
# Professor:  3494
#
# Professor:  1987
#
# Professor:  444
#
# Professor:  443
#
# Professor:  1055
#
# Professor:  1865
#
# Professor:  3382
#
# Professor:  3085
#
# Professor:  1503
#
# Professor:  2624
#
# Professor:  1821
#
# Professor:  1746
#
# Professor:  445
#
# Professor:  2167
#
# Professor:  446
#
# Professor:  2834
#
# Professor:  447
#
# Professor:  1604
#
# Professor:  448
#
# Professor:  2969
#
# Professor:  1796
#
# Professor:  1718
#
# Professor:  449
#
# Professor:  1920
#
# Professor:  4039
#
# Professor:  1808
#
# Professor:  2127
#
# Professor:  450
#
# Professor:  3050
#
# Professor:  451
#
# Professor:  1391
#
# Professor:  4037
#
# Professor:  452
#
# Professor:  453
#
# Professor:  823
#
# Professor:  454
#
# Professor:  1787
#
# Professor:  455
#
# Professor:  456
#
# Professor:  457
#
# Professor:  738
#
# Professor:  942
#
# Professor:  1699
#
# Professor:  459
#
# Professor:  1037
#
# Professor:  3160
#
# Professor:  461
#
# Professor:  462
#
# Professor:  2665
#
# Professor:  1039
#
# Professor:  463
#
# Professor:  2222
#
# Professor:  464
#
# Professor:  1105
#
# Professor:  465
#
# Professor:  2810
#
# Professor:  2608
#
# Professor:  1327
#
# Professor:  2124
#
# Professor:  804
#
# Professor:  466
#
# Professor:  2369
#
# Professor:  2761
#
# Professor:  2679
#
# Professor:  467
#
# Professor:  897
#
# Professor:  1028
#
# Professor:  1234
#
# Professor:  3217
#
# Professor:  469
#
# Professor:  470
#
# Professor:  471
#
# Professor:  472
#
# Professor:  473
#
# Professor:  3315
#
# Professor:  3336
#
# Professor:  4173
#
# Professor:  3049
#
# Professor:  3064
#
# Professor:  2602
#
# Professor:  3549
#
# Professor:  2981
#
# Professor:  1510
#
# Professor:  3366
#
# Professor:  2996
#
# Professor:  4103
#
# Professor:  799
#
# Professor:  474
#
# Professor:  1313
#
# Professor:  2425
#
# Professor:  2356
#
# Professor:  2330
#
# Professor:  2362
#
# Professor:  475
#
# Professor:  476
#
# Professor:  937
#
# Professor:  1163
#
# Professor:  477
#
# Professor:  3012
#
# Professor:  2121
#
# Professor:  1101
#
# Professor:  478
#
# Professor:  2824
#
# Professor:  2611
#
# Professor:  2894
#
# Professor:  4220
#
# Professor:  2815
#
# Professor:  1348
#
# Professor:  1077
#
# Professor:  479
#
# Professor:  926
#
# Professor:  480
#
# Professor:  1353
#
# Professor:  4071
#
# Professor:  4084
#
# Professor:  2391
#
# Professor:  1832
#
# Professor:  4007
#
# Professor:  481
#
# Professor:  482
#
# Professor:  985
#
# Professor:  2940
#
# Professor:  3483
#
# Professor:  843
#
# Professor:  2985
#
# Professor:  483
#
# Professor:  3355
#
# Professor:  2003
#
# Professor:  2788
#
# Professor:  1432
#
# Professor:  2408
#
# Professor:  1759
#
# Professor:  1997
#
# Professor:  1491
#
# Professor:  1015
#
# Professor:  978
#
# Professor:  2405
#
# Professor:  1299
#
# Professor:  485
#
# Professor:  3919
#
# Professor:  2844
#
# Professor:  487
#
# Professor:  486
#
# Professor:  1720
#
# Professor:  1366
#
# Professor:  484
#
# Professor:  2372
#
# Professor:  1497
#
# Professor:  2101
#
# Professor:  4105
#
# Professor:  2382
#
# Professor:  2449
#
# Professor:  3142
#
# Professor:  3117
#
# Professor:  1312
#
# Professor:  3530
#
# Professor:  900
#
# Professor:  4164
#
# Professor:  2871
#
# Professor:  488
#
# Professor:  922
#
# Professor:  1245
#
# Professor:  489
#
# Professor:  490
#
# Professor:  4217
#
# Professor:  883
#
# Professor:  3890
#
# Professor:  491
#
# Professor:  492
#
# Professor:  1975
#
# Professor:  3470
#
# Professor:  493
#
# Professor:  1590
#
# Professor:  494
#
# Professor:  861
#
# Professor:  1489
#
# Professor:  859
#
# Professor:  2789
#
# Professor:  1619
#
# Professor:  2615
#
# Professor:  495
#
# Professor:  927
#
# Professor:  496
#
# Professor:  1783
#
# Professor:  2327
#
# Professor:  497
#
# Professor:  1837
#
# Professor:  498
#
# Professor:  499
#
# Professor:  4012
#
# Professor:  2139
#
# Professor:  2771
#
# Professor:  2879
#
# Professor:  808
#
# Professor:  1608
#
# Professor:  3426
#
# Professor:  3507
#
# Professor:  500
#
# Professor:  501
#
# Professor:  1202
#
# Professor:  502
#
# Professor:  1185
#
# Professor:  3375
#
# Professor:  4073
#
# Professor:  504
#
# Professor:  1053
#
# Professor:  3059
#
# Professor:  2748
#
# Professor:  505
#
# Professor:  3069
#
# Professor:  507
#
# Professor:  506
#
# Professor:  4119
#
# Professor:  1244
#
# Professor:  4063
#
# Professor:  1227
#
# Professor:  2174
#
# Professor:  928
#
# Professor:  878
#
# Professor:  4161
#
# Professor:  508
#
# Professor:  3301
#
# Professor:  2098
#
# Professor:  510
#
# Professor:  4081
#
# Professor:  511
#
# Professor:  4095
#
# Professor:  1979
#
# Professor:  1369
#
# Professor:  3551
#
# Professor:  1722
#
# Professor:  1545
#
# Professor:  3063
#
# Professor:  3720
#
# Professor:  3896
#
# Professor:  512
#
# Professor:  513
#
# Professor:  516
#
# Professor:  514
#
# Professor:  1648
#
# Professor:  515
#
# Professor:  1434
#
# Professor:  2876
#
# Professor:  1283
#
# Professor:  1577
#
# Professor:  517
#
# Professor:  1596
#
# Professor:  1480
#
# Professor:  518
#
# Professor:  519
#
# Professor:  2036
#
# Professor:  918
#
# Professor:  2350
#
# Professor:  4070
#
# Professor:  1523
#
# Professor:  1621
#
# Professor:  520
#
# Professor:  2149
#
# Professor:  521
#
# Professor:  522
#
# Professor:  742
#
# Professor:  4125
#
# Professor:  3352
#
# Professor:  4059
#
# Professor:  2102
#
# Professor:  2866
#
# Professor:  4100
#
# Professor:  3734
#
# Professor:  3300
#
# Professor:  2312
#
# Professor:  4019
#
# Professor:  3037
#
# Professor:  3100
#
# Professor:  524
#
# Professor:  4030
#
# Professor:  4116
#
# Professor:  4010
#
# Professor:  973
#
# Professor:  4022
#
# Professor:  525
#
# Professor:  526
#
# Professor:  3942
#
# Professor:  527
#
# Professor:  2455
#
# Professor:  1575
#
# Professor:  3016
#
# Professor:  528
#
# Professor:  2034
#
# Professor:  3093
#
# Professor:  3040
#
# Professor:  1416
#
# Professor:  2347
#
# Professor:  1310
#
# Professor:  814
#
# Professor:  1350
#
# Professor:  1399
#
# Professor:  1183
#
# Professor:  2105
#
# Professor:  1128
#
# Professor:  2614
#
# Professor:  2396
#
# Professor:  4200
#
# Professor:  529
#
# Professor:  3687
#
# Professor:  530
#
# Professor:  1280
#
# Professor:  531
#
# Professor:  532
#
# Professor:  3722
#
# Professor:  3958
#
# Professor:  3092
#
# Professor:  533
#
# Professor:  1440
#
# Professor:  534
#
# Professor:  4146
#
# Professor:  1247
#
# Professor:  4169
#
# Professor:  3115
#
# Professor:  4181
#
# Professor:  1861
#
# Professor:  1030
#
# Professor:  1594
#
# Professor:  2740
#
# Professor:  535
#
# Professor:  2942
#
# Professor:  911
#
# Professor:  2106
#
# Professor:  3972
#
# Professor:  3721
#
# Professor:  1190
#
# Professor:  1298
#
# Professor:  1433
#
# Professor:  2965
#
# Professor:  3518
#
# Professor:  536
#
# Professor:  537
#
# Professor:  2354
#
# Professor:  1838
#
# Professor:  885
#
# Professor:  1786
#
# Professor:  538
#
# Professor:  850
#
# Professor:  539
#
# Professor:  4210
#
# Professor:  1274
#
# Professor:  1784
#
# Professor:  1306
#
# Professor:  1285
#
# Professor:  4062
#
# Professor:  2433
#
# Professor:  4198
#
# Professor:  540
#
# Professor:  541
#
# Professor:  542
#
# Professor:  3161
#
# Professor:  544
#
# Professor:  1059
#
# Professor:  1345
#
# Professor:  3980
#
# Professor:  1032
#
# Professor:  853
#
# Professor:  545
#
# Professor:  1040
#
# Professor:  2691
#
# Professor:  1781
#
# Professor:  546
#
# Professor:  3772
#
# Professor:  1691
#
# Professor:  2355
#
# Professor:  975
#
# Professor:  547
#
# Professor:  2324
#
# Professor:  1613
#
# Professor:  548
#
# Professor:  2069
#
# Professor:  1610
#
# Professor:  3108
#
# Professor:  549
#
# Professor:  4117
#
# Professor:  1527
#
# Professor:  743
#
# Professor:  550
#
# Professor:  551
#
# Professor:  1215
#
# Professor:  1606
#
# Professor:  2947
#
# Professor:  2744
#
# Professor:  1444
#
# Professor:  553
#
# Professor:  3060
#
# Professor:  554
#
# Professor:  822
#
# Professor:  1027
#
# Professor:  555
#
# Professor:  1447
#
# Professor:  2413
#
# Professor:  1164
#
# Professor:  556
#
# Professor:  1741
#
# Professor:  3961
#
# Professor:  557
#
# Professor:  558
#
# Professor:  1210
#
# Professor:  559
#
# Professor:  1679
#
# Professor:  2716
#
# Professor:  560
#
# Professor:  561
#
# Professor:  3935
#
# Professor:  562
#
# Professor:  3381
#
# Professor:  980
#
# Professor:  563
#
# Professor:  2926
#
# Professor:  3159
#
# Professor:  3960
#
# Professor:  2248
#
# Professor:  564
#
# Professor:  565
#
# Professor:  1514
#
# Professor:  3306
#
# Professor:  1123
#
# Professor:  759
#
# Professor:  3390
#
# Professor:  4224
#
# Professor:  1625
#
# Professor:  566
#
# Professor:  2393
#
# Professor:  4132
#
# Professor:  2877
#
# Professor:  567
#
# Professor:  3887
#
# Professor:  4023
#
# Professor:  3948
#
# Professor:  568
#
# Professor:  1383
#
# Professor:  3391
#
# Professor:  1531
#
# Professor:  1137
#
# Professor:  920
#
# Professor:  3971
#
# Professor:  3513
#
# Professor:  1319
#
# Professor:  569
#
# Professor:  570
#
# Professor:  2117
#
# Professor:  572
#
# Professor:  2151
#
# Professor:  573
#
# Professor:  2713
#
# Professor:  893
#
# Professor:  574
#
# Professor:  1453
#
# Professor:  1558
#
# Professor:  575
#
# Professor:  3363
#
# Professor:  3751
#
# Professor:  576
#
# Professor:  577
#
# Professor:  3949
#
# Professor:  578
#
# Professor:  3157
#
# Professor:  1303
#
# Professor:  2063
#
# Professor:  4002
#
# Professor:  857
#
# Professor:  579
#
# Professor:  580
#
# Professor:  1143
#
# Professor:  1235
#
# Professor:  2753
#
# Professor:  581
#
# Professor:  3743
#
# Professor:  582
#
# Professor:  2891
#
# Professor:  583
#
# Professor:  584
#
# Professor:  585
#
# Professor:  992
#
# Professor:  3031
#
# Professor:  1844
#
# Professor:  586
#
# Professor:  587
#
# Professor:  3032
#
# Professor:  588
#
# Professor:  1818
#
# Professor:  1328
#
# Professor:  1587
#
# Professor:  3307
#
# Professor:  589
#
# Professor:  1436
#
# Professor:  1714
#
# Professor:  3082
#
# Professor:  590
#
# Professor:  2050
#
# Professor:  591
#
# Professor:  592
#
# Professor:  2065
#
# Professor:  593
#
# Professor:  749
#
# Professor:  1499
#
# Professor:  594
#
# Professor:  595
#
# Professor:  596
#
# Professor:  3956
#
# Professor:  2130
#
# Professor:  1475
#
# Professor:  2968
#
# Professor:  597
#
# Professor:  4226
#
# Professor:  598
#
# Professor:  2453
#
# Professor:  2612
#
# Professor:  2868
#
# Professor:  1677
#
# Professor:  2977
#
# Professor:  2328
#
# Professor:  1519
#
# Professor:  3094
#
# Professor:  599
#
# Professor:  972
#
# Professor:  1355
#
# Professor:  1139
#
# Professor:  3905
#
# Professor:  929
#
# Professor:  3367
#
# Professor:  1045
#
# Professor:  3029
#
# Professor:  2825
#
# Professor:  1049
#
# Professor:  600
#
# Professor:  2530
#
# Professor:  2424
#
# Professor:  601
#
# Professor:  2311
#
# Professor:  1707
#
# Professor:  602
#
# Professor:  603
#
# Professor:  1798
#
# Professor:  3036
#
# Professor:  2392
#
# Professor:  1352
#
# Professor:  2962
#
# Professor:  2609
#
# Professor:  604
#
# Professor:  4153
#
# Professor:  2823
#
# Professor:  1036
#
# Professor:  1595
#
# Professor:  1009
#
# Professor:  605
#
# Professor:  1757
#
# Professor:  1267
#
# Professor:  606
#
# Professor:  607
#
# Professor:  2690
#
# Professor:  2681
#
# Professor:  2921
#
# Professor:  3072
#
# Professor:  608
#
# Professor:  4179
#
# Professor:  4177
#
# Professor:  3103
#
# Professor:  612
#
# Professor:  610
#
# Professor:  611
#
# Professor:  613
#
# Professor:  1735
#
# Professor:  4158
#
# Professor:  3998
#
# Professor:  614
#
# Professor:  3485
#
# Professor:  1052
#
# Professor:  615
#
# Professor:  616
#
# Professor:  1469
#
# Professor:  1250
#
# Professor:  3106
#
# Professor:  1116
#
# Professor:  617
#
# Professor:  3499
#
# Professor:  1354
#
# Professor:  3514
#
# Professor:  1653
#
# Professor:  1501
#
# Professor:  863
#
# Professor:  902
#
# Professor:  619
#
# Professor:  618
#
# Professor:  3686
#
# Professor:  3666
#
# Professor:  2060
#
# Professor:  3899
#
# Professor:  3461
#
# Professor:  620
#
# Professor:  4078
#
# Professor:  4042
#
# Professor:  621
#
# Professor:  2629
#
# Professor:  1454
#
# Professor:  622
#
# Professor:  3102
#
# Professor:  837
#
# Professor:  1442
#
# Professor:  1056
#
# Professor:  623
#
# Professor:  994
#
# Professor:  995
#
# Professor:  3749
#
# Professor:  624
#
# Professor:  625
#
# Professor:  2754
#
# Professor:  2120
#
# Professor:  3508
#
# Professor:  991
#
# Professor:  626
#
# Professor:  1233
#
# Professor:  1240
#
# Professor:  4206
#
# Professor:  1708
#
# Professor:  996
#
# Professor:  1517
#
# Professor:  2839
#
# Professor:  1790
#
# Professor:  824
#
# Professor:  627
#
# Professor:  628
#
# Professor:  2830
#
# Professor:  2068
#
# Professor:  1463
#
# Professor:  829
#
# Professor:  2157
#
# Professor:  2538
#
# Professor:  629
#
# Professor:  1134
#
# Professor:  1467
#
# Professor:  630
#
# Professor:  3962
#
# Professor:  631
#
# Professor:  632
#
# Professor:  944
#
# Professor:  4188
#
# Professor:  633
#
# Professor:  2991
#
# Professor:  634
#
# Professor:  635
#
# Professor:  1290
#
# Professor:  636
#
# Professor:  3537
#
# Professor:  1479
#
# Professor:  637
#
# Professor:  1827
#
# Professor:  4069
#
# Professor:  638
#
# Professor:  639
#
# Professor:  1091
#
# Professor:  2857
#
# Professor:  640
#
# Professor:  1754
#
# Professor:  641
#
# Professor:  2381
#
# Professor:  2865
#
# Professor:  977
#
# Professor:  642
#
# Professor:  756
#
# Professor:  1160
#
# Professor:  2960
#
# Professor:  801
#
# Professor:  1388
#
# Professor:  914
#
# Professor:  1692
#
# Professor:  1727
#
# Professor:  2677
#
# Professor:  989
#
# Professor:  2699
#
# Professor:  3005
#
# Professor:  643
#
# Professor:  1730
#
# Professor:  1651
#
# Professor:  2115
#
# Professor:  1919
#
# Professor:  2737
#
# Professor:  1612
#
# Professor:  644
#
# Professor:  2079
#
# Professor:  645
#
# Professor:  646
#
# Professor:  2112
#
# Professor:  1135
#
# Professor:  647
#
# Professor:  648
#
# Professor:  2109
#
# Professor:  1048
#
# Professor:  1988
#
# Professor:  649
#
# Professor:  3974
#
# Professor:  1586
#
# Professor:  2622
#
# Professor:  1672
#
# Professor:  1231
#
# Professor:  1546
#
# Professor:  3895
#
# Professor:  2992
#
# Professor:  1520
#
# Professor:  2893
#
# Professor:  2434
#
# Professor:  650
#
# Professor:  651
#
# Professor:  1680
#
# Professor:  3915
#
# Professor:  1175
#
# Professor:  652
#
# Professor:  825
#
# Professor:  2919
#
# Professor:  834
#
# Professor:  3041
#
# Professor:  793
#
# Professor:  2887
#
# Professor:  654
#
# Professor:  4106
#
# Professor:  655
#
# Professor:  1478
#
# Professor:  656
#
# Professor:  3981
#
# Professor:  657
#
# Professor:  2972
#
# Professor:  3396
#
# Professor:  2903
#
# Professor:  1099
#
# Professor:  4110
#
# Professor:  1880
#
# Professor:  2451
#
# Professor:  1259
#
# Professor:  658
#
# Professor:  1180
#
# Professor:  1307
#
# Professor:  1647
#
# Professor:  659
#
# Professor:  663
#
# Professor:  660
#
# Professor:  1268
#
# Professor:  661
#
# Professor:  662
#
# Professor:  3495
#
# Professor:  664
#
# Professor:  665
#
# Professor:  906
#
# Professor:  3148
#
# Professor:  2873
#
# Professor:  3393
#
# Professor:  667
#
# Professor:  1645
#
# Professor:  4133
#
# Professor:  2783
#
# Professor:  2855
#
# Professor:  1826
#
# Professor:  668
#
# Professor:  1291
#
# Professor:  2446
#
# Professor:  962
#
# Professor:  669
#
# Professor:  670
#
# Professor:  736
#
# Professor:  671
#
# Professor:  672
#
# Professor:  673
#
# Professor:  1887
#
# Professor:  3116
#
# Professor:  4017
#
# Professor:  1683
#
# Professor:  1584
#
# Professor:  4135
#
# Professor:  674
#
# Professor:  675
#
# Professor:  961
#
# Professor:  1464
#
# Professor:  3062
#
# Professor:  1912
#
# Professor:  887
#
# Professor:  862
#
# Professor:  676
#
# Professor:  3977
#
# Professor:  677
#
# Professor:  784
#
# Professor:  678
#
# Professor:  679
#
# Professor:  4053
#
# Professor:  680
#
# Professor:  2955
#
# Professor:  2630
#
# Professor:  681
#
# Professor:  682
#
# Professor:  2085
#
# Professor:  2061
#
# Professor:  1494
#
# Professor:  3022
#
# Professor:  3988
#
# Professor:  3992
#
# Professor:  2715
#
# Professor:  683
#
# Professor:  3356
#
# Professor:  1248
#
# Professor:  684
#
# Professor:  685
#
# Professor:  1132
#
# Professor:  3309
#
# Professor:  4195
#
# Professor:  686
#
# Professor:  2029
#
# Professor:  1102
#
# Professor:  1115
#
# Professor:  1505
#
# Professor:  4054
#
# Professor:  1415
#
# Professor:  687
#
# Professor:  688
#
# Professor:  689
#
# Professor:  690
#
# Professor:  2410
#
# Professor:  1022
#
# Professor:  691
#
# Professor:  1199
#
# Professor:  692
#
# Professor:  4138
#
# Professor:  3920
#
# Professor:  693
#
# Professor:  4096
#
# Professor:  851
#
# Professor:  3973
#
# Professor:  694
#
# Professor:  2545
#
# Professor:  2508
#
# Professor:  753
#
# Professor:  695
#
# Professor:  696
#
# Professor:  697
#
# Professor:  698
#
# Professor:  3469
#
# Professor:  1001
#
# Professor:  4214
#
# Professor:  3384
#
# Professor:  3445
#
# Professor:  699
#
# Professor:  700
#
# Professor:  2774
#
# Professor:  1532
#
# Professor:  1522
#
# Professor:  2980
#
# Professor:  939
#
# Professor:  1451
#
# Professor:  870
#
# Professor:  1431
#
# Professor:  1473
#
# Professor:  967
#
# Professor:  2037
#
# Professor:  935
#
# Professor:  4029
#
# Professor:  2365
#
# Professor:  701
#
# Professor:  2071
#
# Professor:  2805
#
# Professor:  2787
#
# Professor:  702
#
# Professor:  703
#
# Professor:  2506
#
# Professor:  854
#
# Professor:  2898
#
# Professor:  1581
#
# Professor:  704
#
# Professor:  705
#
# Professor:  952
#
# Professor:  2140
#
# Professor:  706
#
# Professor:  707
#
# Professor:  3711
#
# Professor:  709
#
# Professor:  708
#
# Professor:  710
#
# Professor:  711
#
# Professor:  2726
#
# Professor:  712
#
# Professor:  1197
#
# Professor:  1620
#
# Professor:  1905
#
# Professor:  3174
#
# Professor:  713
#
# Professor:  4102
#
# Professor:  2925
#
# Professor:  2247
#
# Professor:  783
#
# Professor:  714
#
# Professor:  2890
#
# Professor:  958
#
# Professor:  1251
#
# Professor:  1824
#
# Professor:  2090
#
# Professor:  715
#
# Professor:  3007
#
# Professor:  1085
#
# Professor:  716
#
# Professor:  2164
#
# Professor:  2516
#
# Professor:  4013
#
# Professor:  4068
#
# Professor:  4166
#
# Professor:  2110
#
# Professor:  3498
#
# Professor:  1034
#
# Professor:  1375
#
# Professor:  2203
#
# Professor:  4108
#
# Professor:  718
#
# Professor:  1549
#
# Professor:  3402
#
# Professor:  2361
#
# Professor:  1417
#
# Professor:  4052
#
# Professor:  3112
#
# Professor:  847
#
# Professor:  719
#
# Professor:  720
#
# Professor:  2943
#
# Professor:  2441
#
# Professor:  721
#
# Professor:  4098
#
# Professor:  3965
#
# Professor:  821
#
# Professor:  805
#
# Professor:  775
#
# Professor:  3076
#
# Professor:  1100
#
# Professor:  1420
#
# Professor:  3416
#
# Professor:  2095
#
# Professor:  722
#
# Professor:  2763
#
# Professor:  3105
#
# Professor:  723
#
# Professor:  724
#
# Professor:  1687
#
# Professor:  1593
#
# Professor:  2104
#
# Professor:  2905
#
# Professor:  1258
#
# Professor:  3045
#
# Professor:  725
#
# Professor:  726
#
# Professor:  3027
#
# Professor:  727
#
# Professor:  1758
#
# Professor:  728

# %%
assert len(professor_frames) == 2416

# %% [markdown]
# ## Inspect the Dataframes

# %%
professors, p_stats, p_stats_by_grade, p_stats_by_year, p_stats_by_grade_list = \
    merge_professors(professor_frames)
# Out:
#                                Dept            Name  Reporting Evaluations
# prof_id
# 2073     Chemistry and Biochemistry  Christina Abel                     32
#    median   mean  std_dev  mode                      rating_type  prof_id
# 0       4  3.563    0.556     4                   Overall Rating     2073
# 1       4  3.594    0.551     4        Presents Material Clearly     2073
# 2       4  3.563    0.658     4  Recognizes Student Difficulties     2073
#                                       A      B     C Credit  D     F  N/A  \
# Overall Rating                    3.769  3.222  3.75   None  3  None    3
# Presents Material Clearly         3.769  3.222  3.75   None  3  None    4
# Recognizes Student Difficulties   3.692  3.222  3.75   None  4  None    3
# Reporting Evaluations            13.000  9.000  8.00   None  1  None    1
#
#                                 No Credit  prof_id
# Overall Rating                       None     2073
# Presents Material Clearly            None     2073
# Recognizes Student Difficulties      None     2073
# Reporting Evaluations                None     2073
#                                 5th Year Senior  Freshman Graduate Student  \
# Overall Rating                             None     3.500             None
# Presents Material Clearly                  None     3.714             None
# Recognizes Student Difficulties            None     3.571             None
# Reporting Evaluations                      None    14.000             None
#
#                                  Junior  Senior  Sophomore  prof_id
# Overall Rating                    4.000   3.333      3.583     2073
# Presents Material Clearly         3.667   3.333      3.500     2073
# Recognizes Student Difficulties   4.000   3.667      3.417     2073
# Reporting Evaluations             3.000   3.000     12.000     2073

# %%
professors.tail()
# Out:
#                                        Dept             Name  \
# prof_id
# 726      Environmental Horticulture Science    Michael Zohns
# 3027                             Philosophy     David Zoller
# 727                         Social Sciences  Maliha Zulfacar
# 1758             Chemistry and Biochemistry    Marta Zumwalt
# 728                            Architecture     Dick Zweifel
#
#          Reporting Evaluations
# prof_id
# 726                          8
# 3027                         9
# 727                         87
# 1758                        13
# 728                         16

# %%
p_stats.tail(10)
# Out:
#       median   mean  std_dev  mode                      rating_type  prof_id
# 5255       0  2.778    1.133     3  Recognizes Student Difficulties     3027
# 5256       0  1.989    1.615     4                   Overall Rating      727
# 5257       0  2.023    1.454     4        Presents Material Clearly      727
# 5258       0  1.839    1.538     0  Recognizes Student Difficulties      727
# 5259       0  2.769    1.367     4                   Overall Rating     1758
# 5260       0  2.923    1.385     4        Presents Material Clearly     1758
# 5261       0  2.462    1.278     2  Recognizes Student Difficulties     1758
# 5262       1  1.625    1.317     1                   Overall Rating      728
# 5263       2  2.375    1.111     2        Presents Material Clearly      728
# 5264       2  1.875    1.166     1  Recognizes Student Difficulties      728

# %%
p_stats_by_grade_list[-3]
# Out:
#                                       A       B      C  Credit    D    F  \
# Overall Rating                    3.125   1.939  0.889     3.0  0.0  1.0
# Presents Material Clearly         2.958   2.000  1.333     2.5  0.0  1.5
# Recognizes Student Difficulties   3.000   1.697  1.000     2.5  0.5  1.0
# Reporting Evaluations            24.000  33.000  9.000     2.0  2.0  2.0
#
#                                     N/A No Credit  prof_id
# Overall Rating                    1.286      None      727
# Presents Material Clearly         1.357      None      727
# Recognizes Student Difficulties   1.071      None      727
# Reporting Evaluations            14.000      None      727

# %%
#THis takes a long, long time to run. 
#Prints out the professor ID of the professor that it's processing.
professor_reviews = get_all_profs_reviews(good_professor_urls)
# Out:
# Professor Id:  2073
# Professor Id:  2390
# Professor Id:  2429
# Professor Id:  1
# Professor Id:  2
# Professor Id:  746
# Professor Id:  3
# Professor Id:  1252
# Professor Id:  2819
# Professor Id:  1693
# Professor Id:  2236
# Professor Id:  1617
# Professor Id:  4
# Professor Id:  1007
# Professor Id:  5
# Professor Id:  3351
# Professor Id:  4126
# Professor Id:  6
# Professor Id:  908
# Professor Id:  1095
# Professor Id:  4008
# Professor Id:  4167
# Professor Id:  2950
# Professor Id:  1418
# Professor Id:  2375
# Professor Id:  990
# Professor Id:  1748
# Professor Id:  974
# Professor Id:  778
# Professor Id:  7
# Professor Id:  2797
# Professor Id:  3452
# Professor Id:  3894
# Professor Id:  2089
# Professor Id:  8
# Professor Id:  9
# Professor Id:  10
# Professor Id:  891
# Professor Id:  11
# Professor Id:  2820
# Professor Id:  1403
# Professor Id:  2374
# Professor Id:  3035
# Professor Id:  4050
# Professor Id:  12
# Professor Id:  13
# Professor Id:  3500
# Professor Id:  2712
# Professor Id:  2739
# Professor Id:  3126
# Professor Id:  1991
# Professor Id:  14
# Professor Id:  1646
# Professor Id:  4168
# Professor Id:  2126
# Professor Id:  964
# Professor Id:  4172
# Professor Id:  965
# Professor Id:  852
# Professor Id:  1035
# Professor Id:  1736
# Professor Id:  3608
# Professor Id:  777
# Professor Id:  15
# Professor Id:  4140
# Professor Id:  1534
# Professor Id:  4112
# Professor Id:  1457
# Professor Id:  1158
# Professor Id:  3442
# Professor Id:  1114
# Professor Id:  17
# Professor Id:  18
# Professor Id:  3538
# Professor Id:  19
# Professor Id:  3625
# Professor Id:  888
# Professor Id:  2944
# Professor Id:  20
# Professor Id:  1317
# Professor Id:  4004
# Professor Id:  21
# Professor Id:  2904
# Professor Id:  2146
# Professor Id:  3068
# Professor Id:  971
# Professor Id:  2953
# Professor Id:  2082
# Professor Id:  2141
# Professor Id:  22
# Professor Id:  940
# Professor Id:  999
# Professor Id:  1387
# Professor Id:  23
# Professor Id:  24
# Professor Id:  1551
# Professor Id:  2997
# Professor Id:  901
# Professor Id:  4121
# Professor Id:  25
# Professor Id:  3052
# Professor Id:  26
# Professor Id:  1092
# Professor Id:  4131
# Professor Id:  4225
# Professor Id:  4216
# Professor Id:  2150
# Professor Id:  1301
# Professor Id:  27
# Professor Id:  28
# Professor Id:  1694
# Professor Id:  3441
# Professor Id:  29
# Professor Id:  2742
# Professor Id:  2340
# Professor Id:  3986
# Professor Id:  30
# Professor Id:  2798
# Professor Id:  4122
# Professor Id:  3026
# Professor Id:  2902
# Professor Id:  4178
# Professor Id:  988
# Professor Id:  31
# Professor Id:  32
# Professor Id:  33
# Professor Id:  3966
# Professor Id:  34
# Professor Id:  2012
# Professor Id:  1427
# Professor Id:  1419
# Professor Id:  35
# Professor Id:  36
# Professor Id:  4156
# Professor Id:  877
# Professor Id:  1738
# Professor Id:  37
# Professor Id:  2993
# Professor Id:  38
# Professor Id:  4027
# Professor Id:  1141
# Professor Id:  2928
# Professor Id:  2883
# Professor Id:  1481
# Professor Id:  1868
# Professor Id:  39
# Professor Id:  4044
# Professor Id:  40
# Professor Id:  3011
# Professor Id:  3991
# Professor Id:  788
# Professor Id:  2916
# Professor Id:  1430
# Professor Id:  41
# Professor Id:  4174
# Professor Id:  2850
# Professor Id:  1296
# Professor Id:  42
# Professor Id:  43
# Professor Id:  3055
# Professor Id:  1364
# Professor Id:  44
# Professor Id:  45
# Professor Id:  47
# Professor Id:  48
# Professor Id:  49
# Professor Id:  3967
# Professor Id:  50
# Professor Id:  3218
# Professor Id:  2406
# Professor Id:  51
# Professor Id:  889
# Professor Id:  1812
# Professor Id:  1151
# Professor Id:  52
# Professor Id:  53
# Professor Id:  2097
# Professor Id:  3425
# Professor Id:  1063
# Professor Id:  3536
# Professor Id:  54
# Professor Id:  55
# Professor Id:  1064
# Professor Id:  2125
# Professor Id:  1340
# Professor Id:  1772
# Professor Id:  2718
# Professor Id:  1154
# Professor Id:  56
# Professor Id:  57
# Professor Id:  2462
# Professor Id:  58
# Professor Id:  2782
# Professor Id:  957
# Professor Id:  59
# Professor Id:  3019
# Professor Id:  4015
# Professor Id:  1269
# Professor Id:  60
# Professor Id:  61
# Professor Id:  2694
# Professor Id:  1044
# Professor Id:  2711
# Professor Id:  62
# Professor Id:  4144
# Professor Id:  63
# Professor Id:  2867
# Professor Id:  873
# Professor Id:  858
# Professor Id:  64
# Professor Id:  4120
# Professor Id:  1119
# Professor Id:  65
# Professor Id:  4221
# Professor Id:  2360
# Professor Id:  66
# Professor Id:  1315
# Professor Id:  3343
# Professor Id:  2948
# Professor Id:  67
# Professor Id:  68
# Professor Id:  2964
# Professor Id:  800
# Professor Id:  69
# Professor Id:  3819
# Professor Id:  913
# Professor Id:  4092
# Professor Id:  70
# Professor Id:  836
# Professor Id:  1710
# Professor Id:  1242
# Professor Id:  2907
# Professor Id:  3329
# Professor Id:  1070
# Professor Id:  3943
# Professor Id:  1330
# Professor Id:  3993
# Professor Id:  71
# Professor Id:  4183
# Professor Id:  72
# Professor Id:  73
# Professor Id:  1960
# Professor Id:  74
# Professor Id:  76
# Professor Id:  77
# Professor Id:  2910
# Professor Id:  75
# Professor Id:  1150
# Professor Id:  79
# Professor Id:  78
# Professor Id:  758
# Professor Id:  3947
# Professor Id:  80
# Professor Id:  3015
# Professor Id:  81
# Professor Id:  1776
# Professor Id:  82
# Professor Id:  2475
# Professor Id:  2974
# Professor Id:  1591
# Professor Id:  83
# Professor Id:  1556
# Professor Id:  2116
# Professor Id:  1461
# Professor Id:  84
# Professor Id:  796
# Professor Id:  1225
# Professor Id:  3913
# Professor Id:  3990
# Professor Id:  85
# Professor Id:  3299
# Professor Id:  3964
# Professor Id:  3903
# Professor Id:  1490
# Professor Id:  2454
# Professor Id:  3989
# Professor Id:  86
# Professor Id:  2515
# Professor Id:  1541
# Professor Id:  87
# Professor Id:  2817
# Professor Id:  88
# Professor Id:  3444
# Professor Id:  1181
# Professor Id:  2818
# Professor Id:  1742
# Professor Id:  2617
# Professor Id:  2682
# Professor Id:  89
# Professor Id:  2963
# Professor Id:  2922
# Professor Id:  2404
# Professor Id:  1745
# Professor Id:  3362
# Professor Id:  3451
# Professor Id:  4208
# Professor Id:  3066
# Professor Id:  2889
# Professor Id:  90
# Professor Id:  4170
# Professor Id:  2831
# Professor Id:  2728
# Professor Id:  747
# Professor Id:  1062
# Professor Id:  4185
# Professor Id:  91
# Professor Id:  3939
# Professor Id:  92
# Professor Id:  93
# Professor Id:  94
# Professor Id:  3985
# Professor Id:  2135
# Professor Id:  1624
# Professor Id:  1263
# Professor Id:  2759
# Professor Id:  3898
# Professor Id:  95
# Professor Id:  2720
# Professor Id:  96
# Professor Id:  1278
# Professor Id:  97
# Professor Id:  98
# Professor Id:  3979
# Professor Id:  99
# Professor Id:  100
# Professor Id:  1236
# Professor Id:  3496
# Professor Id:  101
# Professor Id:  1822
# Professor Id:  2459
# Professor Id:  1359
# Professor Id:  102
# Professor Id:  1341
# Professor Id:  2227
# Professor Id:  2367
# Professor Id:  2557
# Professor Id:  925
# Professor Id:  3959
# Professor Id:  2653
# Professor Id:  103
# Professor Id:  1176
# Professor Id:  2191
# Professor Id:  2777
# Professor Id:  3090
# Professor Id:  3515
# Professor Id:  104
# Professor Id:  105
# Professor Id:  106
# Professor Id:  4035
# Professor Id:  4034
# Professor Id:  1220
# Professor Id:  1540
# Professor Id:  1323
# Professor Id:  107
# Professor Id:  108
# Professor Id:  1408
# Professor Id:  1921
# Professor Id:  2658
# Professor Id:  2987
# Professor Id:  109
# Professor Id:  813
# Professor Id:  110
# Professor Id:  111
# Professor Id:  2250
# Professor Id:  4222
# Professor Id:  112
# Professor Id:  1896
# Professor Id:  114
# Professor Id:  113
# Professor Id:  1147
# Professor Id:  1379
# Professor Id:  1774
# Professor Id:  1347
# Professor Id:  2138
# Professor Id:  115
# Professor Id:  2155
# Professor Id:  1810
# Professor Id:  1021
# Professor Id:  116
# Professor Id:  2854
# Professor Id:  1570
# Professor Id:  4047
# Professor Id:  969
# Professor Id:  2348
# Professor Id:  2417
# Professor Id:  117
# Professor Id:  879
# Professor Id:  118
# Professor Id:  1860
# Professor Id:  1316
# Professor Id:  1747
# Professor Id:  1193
# Professor Id:  2870
# Professor Id:  828
# Professor Id:  119
# Professor Id:  1640
# Professor Id:  3928
# Professor Id:  120
# Professor Id:  1104
# Professor Id:  121
# Professor Id:  122
# Professor Id:  2859
# Professor Id:  123
# Professor Id:  4176
# Professor Id:  124
# Professor Id:  869
# Professor Id:  4101
# Professor Id:  4180
# Professor Id:  125
# Professor Id:  126
# Professor Id:  127
# Professor Id:  2527
# Professor Id:  2412
# Professor Id:  128
# Professor Id:  1194
# Professor Id:  129
# Professor Id:  1047
# Professor Id:  130
# Professor Id:  131
# Professor Id:  931
# Professor Id:  1767
# Professor Id:  132
# Professor Id:  1054
# Professor Id:  2734
# Professor Id:  2750
# Professor Id:  2054
# Professor Id:  3054
# Professor Id:  1172
# Professor Id:  133
# Professor Id:  134
# Professor Id:  2885
# Professor Id:  2144
# Professor Id:  1878
# Professor Id:  3048
# Professor Id:  135
# Professor Id:  950
# Professor Id:  1005
# Professor Id:  1717
# Professor Id:  1471
# Professor Id:  966
# Professor Id:  136
# Professor Id:  1011
# Professor Id:  2049
# Professor Id:  137
# Professor Id:  1739
# Professor Id:  139
# Professor Id:  955
# Professor Id:  140
# Professor Id:  141
# Professor Id:  1508
# Professor Id:  907
# Professor Id:  2796
# Professor Id:  2801
# Professor Id:  142
# Professor Id:  1122
# Professor Id:  143
# Professor Id:  4032
# Professor Id:  3322
# Professor Id:  4141
# Professor Id:  1177
# Professor Id:  144
# Professor Id:  145
# Professor Id:  146
# Professor Id:  147
# Professor Id:  148
# Professor Id:  2059
# Professor Id:  1013
# Professor Id:  1544
# Professor Id:  2812
# Professor Id:  2132
# Professor Id:  149
# Professor Id:  1155
# Professor Id:  3917
# Professor Id:  1293
# Professor Id:  150
# Professor Id:  3607
# Professor Id:  3968
# Professor Id:  151
# Professor Id:  865
# Professor Id:  152
# Professor Id:  982
# Professor Id:  1470
# Professor Id:  924
# Professor Id:  1249
# Professor Id:  846
# Professor Id:  1138
# Professor Id:  3211
# Professor Id:  3719
# Professor Id:  153
# Professor Id:  4143
# Professor Id:  2368
# Professor Id:  2371
# Professor Id:  4028
# Professor Id:  2152
# Professor Id:  4151
# Professor Id:  154
# Professor Id:  856
# Professor Id:  1421
# Professor Id:  155
# Professor Id:  1284
# Professor Id:  1462
# Professor Id:  1332
# Professor Id:  1635
# Professor Id:  156
# Professor Id:  157
# Professor Id:  1358
# Professor Id:  1778
# Professor Id:  1561
# Professor Id:  158
# Professor Id:  159
# Professor Id:  160
# Professor Id:  4137
# Professor Id:  1219
# Professor Id:  161
# Professor Id:  4048
# Professor Id:  3388
# Professor Id:  1598
# Professor Id:  3946
# Professor Id:  1487
# Professor Id:  2946
# Professor Id:  162
# Professor Id:  163
# Professor Id:  3418
# Professor Id:  164
# Professor Id:  165
# Professor Id:  2827
# Professor Id:  2792
# Professor Id:  166
# Professor Id:  4057
# Professor Id:  1370
# Professor Id:  1111
# Professor Id:  2257
# Professor Id:  167
# Professor Id:  3908
# Professor Id:  1362
# Professor Id:  2067
# Professor Id:  3084
# Professor Id:  2747
# Professor Id:  168
# Professor Id:  1075
# Professor Id:  169
# Professor Id:  170
# Professor Id:  4058
# Professor Id:  2055
# Professor Id:  1257
# Professor Id:  986
# Professor Id:  171
# Professor Id:  172
# Professor Id:  1719
# Professor Id:  1320
# Professor Id:  2635
# Professor Id:  2725
# Professor Id:  173
# Professor Id:  941
# Professor Id:  1484
# Professor Id:  3114
# Professor Id:  174
# Professor Id:  4003
# Professor Id:  2770
# Professor Id:  2221
# Professor Id:  976
# Professor Id:  2758
# Professor Id:  1852
# Professor Id:  2843
# Professor Id:  2835
# Professor Id:  175
# Professor Id:  3110
# Professor Id:  176
# Professor Id:  739
# Professor Id:  916
# Professor Id:  177
# Professor Id:  4163
# Professor Id:  178
# Professor Id:  179
# Professor Id:  180
# Professor Id:  4201
# Professor Id:  2133
# Professor Id:  1346
# Professor Id:  3953
# Professor Id:  3969
# Professor Id:  2321
# Professor Id:  181
# Professor Id:  1582
# Professor Id:  3028
# Professor Id:  3914
# Professor Id:  3978
# Professor Id:  2842
# Professor Id:  182
# Professor Id:  183
# Professor Id:  2722
# Professor Id:  3077
# Professor Id:  2153
# Professor Id:  1382
# Professor Id:  3044
# Professor Id:  184
# Professor Id:  4199
# Professor Id:  1363
# Professor Id:  2768
# Professor Id:  1012
# Professor Id:  1335
# Professor Id:  3010
# Professor Id:  185
# Professor Id:  2445
# Professor Id:  2598
# Professor Id:  4165
# Professor Id:  1162
# Professor Id:  1961
# Professor Id:  872
# Professor Id:  186
# Professor Id:  187
# Professor Id:  4124
# Professor Id:  188
# Professor Id:  189
# Professor Id:  3952
# Professor Id:  2310
# Professor Id:  190
# Professor Id:  3619
# Professor Id:  3365
# Professor Id:  757
# Professor Id:  3440
# Professor Id:  191
# Professor Id:  1096
# Professor Id:  3376
# Professor Id:  193
# Professor Id:  2888
# Professor Id:  3121
# Professor Id:  2450
# Professor Id:  2387
# Professor Id:  3378
# Professor Id:  4065
# Professor Id:  4074
# Professor Id:  2107
# Professor Id:  3408
# Professor Id:  194
# Professor Id:  1724
# Professor Id:  195
# Professor Id:  1597
# Professor Id:  782
# Professor Id:  196
# Professor Id:  1050
# Professor Id:  2289
# Professor Id:  2187
# Professor Id:  197
# Professor Id:  2223
# Professor Id:  1325
# Professor Id:  2432
# Professor Id:  198
# Professor Id:  3929
# Professor Id:  1509
# Professor Id:  1378
# Professor Id:  1377
# Professor Id:  199
# Professor Id:  201
# Professor Id:  3368
# Professor Id:  3369
# Professor Id:  202
# Professor Id:  1006
# Professor Id:  833
# Professor Id:  1843
# Professor Id:  2607
# Professor Id:  1807
# Professor Id:  203
# Professor Id:  204
# Professor Id:  1782
# Professor Id:  205
# Professor Id:  3061
# Professor Id:  3308
# Professor Id:  2752
# Professor Id:  206
# Professor Id:  1777
# Professor Id:  1831
# Professor Id:  207
# Professor Id:  1106
# Professor Id:  208
# Professor Id:  209
# Professor Id:  4160
# Professor Id:  3353
# Professor Id:  1828
# Professor Id:  765
# Professor Id:  210
# Professor Id:  842
# Professor Id:  3688
# Professor Id:  211
# Professor Id:  2075
# Professor Id:  212
# Professor Id:  213
# Professor Id:  2544
# Professor Id:  214
# Professor Id:  216
# Professor Id:  215
# Professor Id:  2091
# Professor Id:  217
# Professor Id:  896
# Professor Id:  1795
# Professor Id:  1689
# Professor Id:  3902
# Professor Id:  4060
# Professor Id:  218
# Professor Id:  1020
# Professor Id:  219
# Professor Id:  3911
# Professor Id:  2929
# Professor Id:  791
# Professor Id:  220
# Professor Id:  3162
# Professor Id:  221
# Professor Id:  1535
# Professor Id:  794
# Professor Id:  222
# Professor Id:  4147
# Professor Id:  2858
# Professor Id:  223
# Professor Id:  224
# Professor Id:  225
# Professor Id:  803
# Professor Id:  1051
# Professor Id:  2318
# Professor Id:  763
# Professor Id:  1089
# Professor Id:  1906
# Professor Id:  1904
# Professor Id:  1165
# Professor Id:  1928
# Professor Id:  226
# Professor Id:  787
# Professor Id:  2351
# Professor Id:  2419
# Professor Id:  1019
# Professor Id:  200
# Professor Id:  2159
# Professor Id:  933
# Professor Id:  2802
# Professor Id:  2978
# Professor Id:  3018
# Professor Id:  1033
# Professor Id:  1201
# Professor Id:  227
# Professor Id:  1871
# Professor Id:  228
# Professor Id:  229
# Professor Id:  2828
# Professor Id:  4049
# Professor Id:  3529
# Professor Id:  2927
# Professor Id:  946
# Professor Id:  1426
# Professor Id:  3934
# Professor Id:  1302
# Professor Id:  503
# Professor Id:  3386
# Professor Id:  2337
# Professor Id:  1931
# Professor Id:  230
# Professor Id:  231
# Professor Id:  3750
# Professor Id:  232
# Professor Id:  1763
# Professor Id:  1785
# Professor Id:  1014
# Professor Id:  233
# Professor Id:  234
# Professor Id:  235
# Professor Id:  236
# Professor Id:  3996
# Professor Id:  871
# Professor Id:  237
# Professor Id:  238
# Professor Id:  240
# Professor Id:  1398
# Professor Id:  241
# Professor Id:  242
# Professor Id:  960
# Professor Id:  1393
# Professor Id:  243
# Professor Id:  1412
# Professor Id:  244
# Professor Id:  1669
# Professor Id:  1329
# Professor Id:  1495
# Professor Id:  3025
# Professor Id:  3034
# Professor Id:  1216
# Professor Id:  245
# Professor Id:  1667
# Professor Id:  246
# Professor Id:  247
# Professor Id:  1732
# Professor Id:  3468
# Professor Id:  1127
# Professor Id:  2610
# Professor Id:  2147
# Professor Id:  998
# Professor Id:  248
# Professor Id:  249
# Professor Id:  1659
# Professor Id:  2683
# Professor Id:  250
# Professor Id:  1496
# Professor Id:  3511
# Professor Id:  1537
# Professor Id:  1605
# Professor Id:  4038
# Professor Id:  4011
# Professor Id:  1429
# Professor Id:  4227
# Professor Id:  251
# Professor Id:  2314
# Professor Id:  2064
# Professor Id:  252
# Professor Id:  2945
# Professor Id:  4207
# Professor Id:  3460
# Professor Id:  253
# Professor Id:  1800
# Professor Id:  818
# Professor Id:  254
# Professor Id:  802
# Professor Id:  1260
# Professor Id:  909
# Professor Id:  1130
# Professor Id:  255
# Professor Id:  1322
# Professor Id:  256
# Professor Id:  2094
# Professor Id:  2078
# Professor Id:  1839
# Professor Id:  1498
# Professor Id:  1876
# Professor Id:  4171
# Professor Id:  4113
# Professor Id:  257
# Professor Id:  4204
# Professor Id:  258
# Professor Id:  910
# Professor Id:  1314
# Professor Id:  2619
# Professor Id:  2721
# Professor Id:  2662
# Professor Id:  1737
# Professor Id:  1326
# Professor Id:  2932
# Professor Id:  827
# Professor Id:  1734
# Professor Id:  983
# Professor Id:  1112
# Professor Id:  259
# Professor Id:  3409
# Professor Id:  2803
# Professor Id:  1696
# Professor Id:  260
# Professor Id:  3039
# Professor Id:  261
# Professor Id:  1450
# Professor Id:  2134
# Professor Id:  262
# Professor Id:  1907
# Professor Id:  3071
# Professor Id:  263
# Professor Id:  3128
# Professor Id:  1626
# Professor Id:  264
# Professor Id:  2924
# Professor Id:  3884
# Professor Id:  2062
# Professor Id:  1762
# Professor Id:  1639
# Professor Id:  265
# Professor Id:  267
# Professor Id:  268
# Professor Id:  269
# Professor Id:  270
# Professor Id:  271
# Professor Id:  272
# Professor Id:  1031
# Professor Id:  4094
# Professor Id:  3030
# Professor Id:  273
# Professor Id:  274
# Professor Id:  1602
# Professor Id:  1410
# Professor Id:  3067
# Professor Id:  1422
# Professor Id:  2123
# Professor Id:  4006
# Professor Id:  1797
# Professor Id:  1239
# Professor Id:  275
# Professor Id:  276
# Professor Id:  1149
# Professor Id:  3944
# Professor Id:  2804
# Professor Id:  277
# Professor Id:  2332
# Professor Id:  278
# Professor Id:  4150
# Professor Id:  279
# Professor Id:  3950
# Professor Id:  1381
# Professor Id:  280
# Professor Id:  2881
# Professor Id:  1673
# Professor Id:  2869
# Professor Id:  923
# Professor Id:  1339
# Professor Id:  4072
# Professor Id:  1367
# Professor Id:  1142
# Professor Id:  282
# Professor Id:  2364
# Professor Id:  283
# Professor Id:  1486
# Professor Id:  1351
# Professor Id:  1232
# Professor Id:  895
# Professor Id:  2166
# Professor Id:  943
# Professor Id:  4020
# Professor Id:  2736
# Professor Id:  2762
# Professor Id:  2791
# Professor Id:  2786
# Professor Id:  886
# Professor Id:  2934
# Professor Id:  2118
# Professor Id:  284
# Professor Id:  285
# Professor Id:  1585
# Professor Id:  1723
# Professor Id:  1459
# Professor Id:  286
# Professor Id:  1607
# Professor Id:  3717
# Professor Id:  287
# Professor Id:  288
# Professor Id:  289
# Professor Id:  1191
# Professor Id:  2998
# Professor Id:  290
# Professor Id:  291
# Professor Id:  1665
# Professor Id:  1109
# Professor Id:  2346
# Professor Id:  292
# Professor Id:  2769
# Professor Id:  4067
# Professor Id:  293
# Professor Id:  294
# Professor Id:  3710
# Professor Id:  1791
# Professor Id:  930
# Professor Id:  2723
# Professor Id:  1108
# Professor Id:  295
# Professor Id:  2973
# Professor Id:  2485
# Professor Id:  1174
# Professor Id:  296
# Professor Id:  1342
# Professor Id:  2729
# Professor Id:  1365
# Professor Id:  297
# Professor Id:  2936
# Professor Id:  298
# Professor Id:  1525
# Professor Id:  3111
# Professor Id:  2951
# Professor Id:  299
# Professor Id:  300
# Professor Id:  301
# Professor Id:  2892
# Professor Id:  830
# Professor Id:  302
# Professor Id:  303
# Professor Id:  2158
# Professor Id:  762
# Professor Id:  3003
# Professor Id:  2601
# Professor Id:  2111
# Professor Id:  1243
# Professor Id:  3492
# Professor Id:  304
# Professor Id:  1873
# Professor Id:  1060
# Professor Id:  2620
# Professor Id:  305
# Professor Id:  1276
# Professor Id:  3083
# Professor Id:  306
# Professor Id:  4136
# Professor Id:  2131
# Professor Id:  307
# Professor Id:  1857
# Professor Id:  2053
# Professor Id:  308
# Professor Id:  309
# Professor Id:  4123
# Professor Id:  1389
# Professor Id:  310
# Professor Id:  3550
# Professor Id:  311
# Professor Id:  2358
# Professor Id:  3024
# Professor Id:  745
# Professor Id:  1533
# Professor Id:  3733
# Professor Id:  312
# Professor Id:  4149
# Professor Id:  2313
# Professor Id:  2316
# Professor Id:  2436
# Professor Id:  2701
# Professor Id:  3350
# Professor Id:  313
# Professor Id:  2335
# Professor Id:  314
# Professor Id:  1308
# Professor Id:  2807
# Professor Id:  2816
# Professor Id:  3674
# Professor Id:  2087
# Professor Id:  2809
# Professor Id:  315
# Professor Id:  1611
# Professor Id:  1170
# Professor Id:  2749
# Professor Id:  1156
# Professor Id:  1305
# Professor Id:  4021
# Professor Id:  316
# Professor Id:  317
# Professor Id:  1373
# Professor Id:  754
# Professor Id:  1511
# Professor Id:  1592
# Professor Id:  2379
# Professor Id:  2394
# Professor Id:  815
# Professor Id:  4091
# Professor Id:  755
# Professor Id:  3149
# Professor Id:  319
# Professor Id:  318
# Professor Id:  320
# Professor Id:  3254
# Professor Id:  2452
# Professor Id:  2440
# Professor Id:  1255
# Professor Id:  321
# Professor Id:  4129
# Professor Id:  3889
# Professor Id:  322
# Professor Id:  750
# Professor Id:  2756
# Professor Id:  1152
# Professor Id:  3342
# Professor Id:  325
# Professor Id:  324
# Professor Id:  323
# Professor Id:  3017
# Professor Id:  2129
# Professor Id:  1811
# Professor Id:  1657
# Professor Id:  326
# Professor Id:  1086
# Professor Id:  3963
# Professor Id:  2195
# Professor Id:  327
# Professor Id:  328
# Professor Id:  1121
# Professor Id:  1753
# Professor Id:  2872
# Professor Id:  867
# Professor Id:  1168
# Professor Id:  2930
# Professor Id:  329
# Professor Id:  330
# Professor Id:  820
# Professor Id:  1103
# Professor Id:  1261
# Professor Id:  331
# Professor Id:  2035
# Professor Id:  4026
# Professor Id:  332
# Professor Id:  4061
# Professor Id:  4203
# Professor Id:  3096
# Professor Id:  1287
# Professor Id:  333
# Professor Id:  1414
# Professor Id:  334
# Professor Id:  4152
# Professor Id:  335
# Professor Id:  2689
# Professor Id:  1010
# Professor Id:  336
# Professor Id:  337
# Professor Id:  2979
# Professor Id:  898
# Professor Id:  932
# Professor Id:  3909
# Professor Id:  2366
# Professor Id:  1265
# Professor Id:  934
# Professor Id:  338
# Professor Id:  2019
# Professor Id:  1559
# Professor Id:  1078
# Professor Id:  339
# Professor Id:  4215
# Professor Id:  1910
# Professor Id:  1682
# Professor Id:  2795
# Professor Id:  2949
# Professor Id:  1304
# Professor Id:  1024
# Professor Id:  1038
# Professor Id:  3079
# Professor Id:  2370
# Professor Id:  340
# Professor Id:  341
# Professor Id:  3101
# Professor Id:  2906
# Professor Id:  3394
# Professor Id:  2552
# Professor Id:  2027
# Professor Id:  2345
# Professor Id:  2781
# Professor Id:  342
# Professor Id:  2569
# Professor Id:  343
# Professor Id:  344
# Professor Id:  840
# Professor Id:  345
# Professor Id:  2826
# Professor Id:  2861
# Professor Id:  2137
# Professor Id:  956
# Professor Id:  899
# Professor Id:  1932
# Professor Id:  2913
# Professor Id:  841
# Professor Id:  346
# Professor Id:  347
# Professor Id:  1333
# Professor Id:  844
# Professor Id:  348
# Professor Id:  349
# Professor Id:  4109
# Professor Id:  350
# Professor Id:  3918
# Professor Id:  351
# Professor Id:  1779
# Professor Id:  352
# Professor Id:  2388
# Professor Id:  2142
# Professor Id:  4064
# Professor Id:  2990
# Professor Id:  3484
# Professor Id:  1192
# Professor Id:  2849
# Professor Id:  1515
# Professor Id:  353
# Professor Id:  1058
# Professor Id:  839
# Professor Id:  354
# Professor Id:  3927
# Professor Id:  1113
# Professor Id:  2937
# Professor Id:  963
# Professor Id:  355
# Professor Id:  4145
# Professor Id:  2163
# Professor Id:  3718
# Professor Id:  2395
# Professor Id:  1107
# Professor Id:  3885
# Professor Id:  1281
# Professor Id:  356
# Professor Id:  3924
# Professor Id:  1148
# Professor Id:  3038
# Professor Id:  1065
# Professor Id:  357
# Professor Id:  4154
# Professor Id:  2918
# Professor Id:  2995
# Professor Id:  4093
# Professor Id:  358
# Professor Id:  3056
# Professor Id:  1637
# Professor Id:  360
# Professor Id:  361
# Professor Id:  1695
# Professor Id:  2621
# Professor Id:  835
# Professor Id:  1067
# Professor Id:  362
# Professor Id:  2908
# Professor Id:  1655
# Professor Id:  4051
# Professor Id:  2917
# Professor Id:  1017
# Professor Id:  363
# Professor Id:  364
# Professor Id:  2790
# Professor Id:  2088
# Professor Id:  2899
# Professor Id:  365
# Professor Id:  2143
# Professor Id:  894
# Professor Id:  4090
# Professor Id:  3073
# Professor Id:  997
# Professor Id:  1756
# Professor Id:  366
# Professor Id:  1631
# Professor Id:  2377
# Professor Id:  4142
# Professor Id:  2160
# Professor Id:  3886
# Professor Id:  1008
# Professor Id:  2700
# Professor Id:  367
# Professor Id:  884
# Professor Id:  4005
# Professor Id:  1814
# Professor Id:  2128
# Professor Id:  2072
# Professor Id:  3033
# Professor Id:  3970
# Professor Id:  3013
# Professor Id:  1989
# Professor Id:  1789
# Professor Id:  368
# Professor Id:  2309
# Professor Id:  2411
# Professor Id:  1448
# Professor Id:  2863
# Professor Id:  912
# Professor Id:  369
# Professor Id:  370
# Professor Id:  371
# Professor Id:  372
# Professor Id:  1094
# Professor Id:  373
# Professor Id:  374
# Professor Id:  375
# Professor Id:  1286
# Professor Id:  376
# Professor Id:  1016
# Professor Id:  1266
# Professor Id:  2336
# Professor Id:  2939
# Professor Id:  2829
# Professor Id:  377
# Professor Id:  1402
# Professor Id:  1385
# Professor Id:  3517
# Professor Id:  2785
# Professor Id:  378
# Professor Id:  3459
# Professor Id:  3415
# Professor Id:  1066
# Professor Id:  379
# Professor Id:  3983
# Professor Id:  1443
# Professor Id:  380
# Professor Id:  1482
# Professor Id:  3047
# Professor Id:  4218
# Professor Id:  1169
# Professor Id:  1662
# Professor Id:  381
# Professor Id:  3736
# Professor Id:  2175
# Professor Id:  382
# Professor Id:  383
# Professor Id:  1823
# Professor Id:  2021
# Professor Id:  3735
# Professor Id:  384
# Professor Id:  385
# Professor Id:  386
# Professor Id:  387
# Professor Id:  1428
# Professor Id:  388
# Professor Id:  751
# Professor Id:  389
# Professor Id:  3443
# Professor Id:  2738
# Professor Id:  779
# Professor Id:  4194
# Professor Id:  2119
# Professor Id:  1750
# Professor Id:  951
# Professor Id:  2793
# Professor Id:  390
# Professor Id:  2882
# Professor Id:  392
# Professor Id:  391
# Professor Id:  979
# Professor Id:  393
# Professor Id:  394
# Professor Id:  981
# Professor Id:  395
# Professor Id:  4184
# Professor Id:  396
# Professor Id:  959
# Professor Id:  2373
# Professor Id:  397
# Professor Id:  398
# Professor Id:  3053
# Professor Id:  399
# Professor Id:  2719
# Professor Id:  1485
# Professor Id:  1504
# Professor Id:  3147
# Professor Id:  1004
# Professor Id:  2435
# Professor Id:  921
# Professor Id:  798
# Professor Id:  400
# Professor Id:  401
# Professor Id:  2308
# Professor Id:  402
# Professor Id:  1000
# Professor Id:  1368
# Professor Id:  1167
# Professor Id:  3389
# Professor Id:  4219
# Professor Id:  2543
# Professor Id:  2315
# Professor Id:  2430
# Professor Id:  2383
# Professor Id:  1153
# Professor Id:  904
# Professor Id:  3994
# Professor Id:  2066
# Professor Id:  403
# Professor Id:  3493
# Professor Id:  3091
# Professor Id:  2172
# Professor Id:  2554
# Professor Id:  3916
# Professor Id:  405
# Professor Id:  404
# Professor Id:  406
# Professor Id:  407
# Professor Id:  2378
# Professor Id:  970
# Professor Id:  408
# Professor Id:  4205
# Professor Id:  1025
# Professor Id:  3097
# Professor Id:  2938
# Professor Id:  2154
# Professor Id:  2733
# Professor Id:  409
# Professor Id:  2864
# Professor Id:  410
# Professor Id:  1124
# Professor Id:  1411
# Professor Id:  2080
# Professor Id:  3453
# Professor Id:  1500
# Professor Id:  2323
# Professor Id:  1855
# Professor Id:  1927
# Professor Id:  2799
# Professor Id:  903
# Professor Id:  2317
# Professor Id:  3907
# Professor Id:  411
# Professor Id:  412
# Professor Id:  1846
# Professor Id:  2541
# Professor Id:  1117
# Professor Id:  3383
# Professor Id:  737
# Professor Id:  4089
# Professor Id:  1618
# Professor Id:  413
# Professor Id:  414
# Professor Id:  4055
# Professor Id:  1850
# Professor Id:  415
# Professor Id:  416
# Professor Id:  987
# Professor Id:  1384
# Professor Id:  3510
# Professor Id:  3014
# Professor Id:  2773
# Professor Id:  1456
# Professor Id:  1343
# Professor Id:  418
# Professor Id:  417
# Professor Id:  419
# Professor Id:  1435
# Professor Id:  420
# Professor Id:  1356
# Professor Id:  2714
# Professor Id:  2874
# Professor Id:  421
# Professor Id:  422
# Professor Id:  2851
# Professor Id:  2853
# Professor Id:  423
# Professor Id:  2092
# Professor Id:  4031
# Professor Id:  752
# Professor Id:  424
# Professor Id:  1277
# Professor Id:  425
# Professor Id:  3888
# Professor Id:  426
# Professor Id:  427
# Professor Id:  428
# Professor Id:  890
# Professor Id:  1061
# Professor Id:  3020
# Professor Id:  1530
# Professor Id:  3501
# Professor Id:  430
# Professor Id:  4041
# Professor Id:  431
# Professor Id:  1676
# Professor Id:  2438
# Professor Id:  2376
# Professor Id:  2384
# Professor Id:  432
# Professor Id:  1069
# Professor Id:  4036
# Professor Id:  1292
# Professor Id:  3087
# Professor Id:  1439
# Professor Id:  1749
# Professor Id:  4056
# Professor Id:  433
# Professor Id:  1521
# Professor Id:  1336
# Professor Id:  434
# Professor Id:  435
# Professor Id:  436
# Professor Id:  437
# Professor Id:  1140
# Professor Id:  1449
# Professor Id:  1057
# Professor Id:  438
# Professor Id:  439
# Professor Id:  2148
# Professor Id:  1488
# Professor Id:  440
# Professor Id:  892
# Professor Id:  4083
# Professor Id:  2074
# Professor Id:  3088
# Professor Id:  3164
# Professor Id:  2329
# Professor Id:  2415
# Professor Id:  1472
# Professor Id:  441
# Professor Id:  4040
# Professor Id:  3051
# Professor Id:  4187
# Professor Id:  442
# Professor Id:  3494
# Professor Id:  1987
# Professor Id:  444
# Professor Id:  443
# Professor Id:  1055
# Professor Id:  1865
# Professor Id:  3382
# Professor Id:  3085
# Professor Id:  1503
# Professor Id:  2624
# Professor Id:  1821
# Professor Id:  1746
# Professor Id:  445
# Professor Id:  2167
# Professor Id:  446
# Professor Id:  2834
# Professor Id:  447
# Professor Id:  1604
# Professor Id:  448
# Professor Id:  2969
# Professor Id:  1796
# Professor Id:  1718
# Professor Id:  449
# Professor Id:  1920
# Professor Id:  4039
# Professor Id:  1808
# Professor Id:  2127
# Professor Id:  450
# Professor Id:  3050
# Professor Id:  451
# Professor Id:  1391
# Professor Id:  4037
# Professor Id:  452
# Professor Id:  453
# Professor Id:  823
# Professor Id:  454
# Professor Id:  1787
# Professor Id:  455
# Professor Id:  456
# Professor Id:  457
# Professor Id:  738
# Professor Id:  942
# Professor Id:  1699
# Professor Id:  459
# Professor Id:  1037
# Professor Id:  3160
# Professor Id:  461
# Professor Id:  462
# Professor Id:  2665
# Professor Id:  1039
# Professor Id:  463
# Professor Id:  2222
# Professor Id:  464
# Professor Id:  1105
# Professor Id:  465
# Professor Id:  2810
# Professor Id:  2608
# Professor Id:  1327
# Professor Id:  2124
# Professor Id:  804
# Professor Id:  466
# Professor Id:  2369
# Professor Id:  2761
# Professor Id:  2679
# Professor Id:  467
# Professor Id:  897
# Professor Id:  1028
# Professor Id:  1234
# Professor Id:  3217
# Professor Id:  469
# Professor Id:  470
# Professor Id:  471
# Professor Id:  472
# Professor Id:  473
# Professor Id:  3315
# Professor Id:  3336
# Professor Id:  4173
# Professor Id:  3049
# Professor Id:  3064
# Professor Id:  2602
# Professor Id:  3549
# Professor Id:  2981
# Professor Id:  1510
# Professor Id:  3366
# Professor Id:  2996
# Professor Id:  4103
# Professor Id:  799
# Professor Id:  474
# Professor Id:  1313
# Professor Id:  2425
# Professor Id:  2356
# Professor Id:  2330
# Professor Id:  2362
# Professor Id:  475
# Professor Id:  476
# Professor Id:  937
# Professor Id:  1163
# Professor Id:  477
# Professor Id:  3012
# Professor Id:  2121
# Professor Id:  1101
# Professor Id:  478
# Professor Id:  2824
# Professor Id:  2611
# Professor Id:  2894
# Professor Id:  4220
# Professor Id:  2815
# Professor Id:  1348
# Professor Id:  1077
# Professor Id:  479
# Professor Id:  926
# Professor Id:  480
# Professor Id:  1353
# Professor Id:  4071
# Professor Id:  4084
# Professor Id:  2391
# Professor Id:  1832
# Professor Id:  4007
# Professor Id:  481
# Professor Id:  482
# Professor Id:  985
# Professor Id:  2940
# Professor Id:  3483
# Professor Id:  843
# Professor Id:  2985
# Professor Id:  483
# Professor Id:  3355
# Professor Id:  2003
# Professor Id:  2788
# Professor Id:  1432
# Professor Id:  2408
# Professor Id:  1759
# Professor Id:  1997
# Professor Id:  1491
# Professor Id:  1015
# Professor Id:  978
# Professor Id:  2405
# Professor Id:  1299
# Professor Id:  485
# Professor Id:  3919
# Professor Id:  2844
# Professor Id:  487
# Professor Id:  486
# Professor Id:  1720
# Professor Id:  1366
# Professor Id:  484
# Professor Id:  2372
# Professor Id:  1497
# Professor Id:  2101
# Professor Id:  4105
# Professor Id:  2382
# Professor Id:  2449
# Professor Id:  3142
# Professor Id:  3117
# Professor Id:  1312
# Professor Id:  3530
# Professor Id:  900
# Professor Id:  4164
# Professor Id:  2871
# Professor Id:  488
# Professor Id:  922
# Professor Id:  1245
# Professor Id:  489
# Professor Id:  490
# Professor Id:  4217
# Professor Id:  883
# Professor Id:  3890
# Professor Id:  491
# Professor Id:  492
# Professor Id:  1975
# Professor Id:  3470
# Professor Id:  493
# Professor Id:  1590
# Professor Id:  494
# Professor Id:  861
# Professor Id:  1489
# Professor Id:  859
# Professor Id:  2789
# Professor Id:  1619
# Professor Id:  2615
# Professor Id:  495
# Professor Id:  927
# Professor Id:  496
# Professor Id:  1783
# Professor Id:  2327
# Professor Id:  497
# Professor Id:  1837
# Professor Id:  498
# Professor Id:  499
# Professor Id:  4012
# Professor Id:  2139
# Professor Id:  2771
# Professor Id:  2879
# Professor Id:  808
# Professor Id:  1608
# Professor Id:  3426
# Professor Id:  3507
# Professor Id:  500
# Professor Id:  501
# Professor Id:  1202
# Professor Id:  502
# Professor Id:  1185
# Professor Id:  3375
# Professor Id:  4073
# Professor Id:  504
# Professor Id:  1053
# Professor Id:  3059
# Professor Id:  2748
# Professor Id:  505
# Professor Id:  3069
# Professor Id:  507
# Professor Id:  506
# Professor Id:  4119
# Professor Id:  1244
# Professor Id:  4063
# Professor Id:  1227
# Professor Id:  2174
# Professor Id:  928
# Professor Id:  878
# Professor Id:  4161
# Professor Id:  508
# Professor Id:  3301
# Professor Id:  2098
# Professor Id:  510
# Professor Id:  4081
# Professor Id:  511
# Professor Id:  4095
# Professor Id:  1979
# Professor Id:  1369
# Professor Id:  3551
# Professor Id:  1722
# Professor Id:  1545
# Professor Id:  3063
# Professor Id:  3720
# Professor Id:  3896
# Professor Id:  512
# Professor Id:  513
# Professor Id:  516
# Professor Id:  514
# Professor Id:  1648
# Professor Id:  515
# Professor Id:  1434
# Professor Id:  2876
# Professor Id:  1283
# Professor Id:  1577
# Professor Id:  517
# Professor Id:  1596
# Professor Id:  1480
# Professor Id:  518
# Professor Id:  519
# Professor Id:  2036
# Professor Id:  918
# Professor Id:  2350
# Professor Id:  4070
# Professor Id:  1523
# Professor Id:  1621
# Professor Id:  520
# Professor Id:  2149
# Professor Id:  521
# Professor Id:  522
# Professor Id:  742
# Professor Id:  4125
# Professor Id:  3352
# Professor Id:  4059
# Professor Id:  2102
# Professor Id:  2866
# Professor Id:  4100
# Professor Id:  3734
# Professor Id:  3300
# Professor Id:  2312
# Professor Id:  4019
# Professor Id:  3037
# Professor Id:  3100
# Professor Id:  524
# Professor Id:  4030
# Professor Id:  4116
# Professor Id:  4010
# Professor Id:  973
# Professor Id:  4022
# Professor Id:  525
# Professor Id:  526
# Professor Id:  3942
# Professor Id:  527
# Professor Id:  2455
# Professor Id:  1575
# Professor Id:  3016
# Professor Id:  528
# Professor Id:  2034
# Professor Id:  3093
# Professor Id:  3040
# Professor Id:  1416
# Professor Id:  2347
# Professor Id:  1310
# Professor Id:  814
# Professor Id:  1350
# Professor Id:  1399
# Professor Id:  1183
# Professor Id:  2105
# Professor Id:  1128
# Professor Id:  2614
# Professor Id:  2396
# Professor Id:  4200
# Professor Id:  529
# Professor Id:  3687
# Professor Id:  530
# Professor Id:  1280
# Professor Id:  531
# Professor Id:  532
# Professor Id:  3722
# Professor Id:  3958
# Professor Id:  3092
# Professor Id:  533
# Professor Id:  1440
# Professor Id:  534
# Professor Id:  4146
# Professor Id:  1247
# Professor Id:  4169
# Professor Id:  3115
# Professor Id:  4181
# Professor Id:  1861
# Professor Id:  1030
# Professor Id:  1594
# Professor Id:  2740
# Professor Id:  535
# Professor Id:  2942
# Professor Id:  911
# Professor Id:  2106
# Professor Id:  3972
# Professor Id:  3721
# Professor Id:  1190
# Professor Id:  1298
# Professor Id:  1433
# Professor Id:  2965
# Professor Id:  3518
# Professor Id:  536
# Professor Id:  537
# Professor Id:  2354
# Professor Id:  1838
# Professor Id:  885
# Professor Id:  1786
# Professor Id:  538
# Professor Id:  850
# Professor Id:  539
# Professor Id:  4210
# Professor Id:  1274
# Professor Id:  1784
# Professor Id:  1306
# Professor Id:  1285
# Professor Id:  4062
# Professor Id:  2433
# Professor Id:  4198
# Professor Id:  540
# Professor Id:  541
# Professor Id:  542
# Professor Id:  3161
# Professor Id:  544
# Professor Id:  1059
# Professor Id:  1345
# Professor Id:  3980
# Professor Id:  1032
# Professor Id:  853
# Professor Id:  545
# Professor Id:  1040
# Professor Id:  2691
# Professor Id:  1781
# Professor Id:  546
# Professor Id:  3772
# Professor Id:  1691
# Professor Id:  2355
# Professor Id:  975
# Professor Id:  547
# Professor Id:  2324
# Professor Id:  1613
# Professor Id:  548
# Professor Id:  2069
# Professor Id:  1610
# Professor Id:  3108
# Professor Id:  549
# Professor Id:  4117
# Professor Id:  1527
# Professor Id:  743
# Professor Id:  550
# Professor Id:  551
# Professor Id:  1215
# Professor Id:  1606
# Professor Id:  2947
# Professor Id:  2744
# Professor Id:  1444
# Professor Id:  553
# Professor Id:  3060
# Professor Id:  554
# Professor Id:  822
# Professor Id:  1027
# Professor Id:  555
# Professor Id:  1447
# Professor Id:  2413
# Professor Id:  1164
# Professor Id:  556
# Professor Id:  1741
# Professor Id:  3961
# Professor Id:  557
# Professor Id:  558
# Professor Id:  1210
# Professor Id:  559
# Professor Id:  1679
# Professor Id:  2716
# Professor Id:  560
# Professor Id:  561
# Professor Id:  3935
# Professor Id:  562
# Professor Id:  3381
# Professor Id:  980
# Professor Id:  563
# Professor Id:  2926
# Professor Id:  3159
# Professor Id:  3960
# Professor Id:  2248
# Professor Id:  564
# Professor Id:  565
# Professor Id:  1514
# Professor Id:  3306
# Professor Id:  1123
# Professor Id:  759
# Professor Id:  3390
# Professor Id:  4224
# Professor Id:  1625
# Professor Id:  566
# Professor Id:  2393
# Professor Id:  4132
# Professor Id:  2877
# Professor Id:  567
# Professor Id:  3887
# Professor Id:  4023
# Professor Id:  3948
# Professor Id:  568
# Professor Id:  1383
# Professor Id:  3391
# Professor Id:  1531
# Professor Id:  1137
# Professor Id:  920
# Professor Id:  3971
# Professor Id:  3513
# Professor Id:  1319
# Professor Id:  569
# Professor Id:  570
# Professor Id:  2117
# Professor Id:  572
# Professor Id:  2151
# Professor Id:  573
# Professor Id:  2713
# Professor Id:  893
# Professor Id:  574
# Professor Id:  1453
# Professor Id:  1558
# Professor Id:  575
# Professor Id:  3363
# Professor Id:  3751
# Professor Id:  576
# Professor Id:  577
# Professor Id:  3949
# Professor Id:  578
# Professor Id:  3157
# Professor Id:  1303
# Professor Id:  2063
# Professor Id:  4002
# Professor Id:  857
# Professor Id:  579
# Professor Id:  580
# Professor Id:  1143
# Professor Id:  1235
# Professor Id:  2753
# Professor Id:  581
# Professor Id:  3743
# Professor Id:  582
# Professor Id:  2891
# Professor Id:  583
# Professor Id:  584
# Professor Id:  585
# Professor Id:  992
# Professor Id:  3031
# Professor Id:  1844
# Professor Id:  586
# Professor Id:  587
# Professor Id:  3032
# Professor Id:  588
# Professor Id:  1818
# Professor Id:  1328
# Professor Id:  1587
# Professor Id:  3307
# Professor Id:  589
# Professor Id:  1436
# Professor Id:  1714
# Professor Id:  3082
# Professor Id:  590
# Professor Id:  2050
# Professor Id:  591
# Professor Id:  592
# Professor Id:  2065
# Professor Id:  593
# Professor Id:  749
# Professor Id:  1499
# Professor Id:  594
# Professor Id:  595
# Professor Id:  596
# Professor Id:  3956
# Professor Id:  2130
# Professor Id:  1475
# Professor Id:  2968
# Professor Id:  597
# Professor Id:  4226
# Professor Id:  598
# Professor Id:  2453
# Professor Id:  2612
# Professor Id:  2868
# Professor Id:  1677
# Professor Id:  2977
# Professor Id:  2328
# Professor Id:  1519
# Professor Id:  3094
# Professor Id:  599
# Professor Id:  972
# Professor Id:  1355
# Professor Id:  1139
# Professor Id:  3905
# Professor Id:  929
# Professor Id:  3367
# Professor Id:  1045
# Professor Id:  3029
# Professor Id:  2825
# Professor Id:  1049
# Professor Id:  600
# Professor Id:  2530
# Professor Id:  2424
# Professor Id:  601
# Professor Id:  2311
# Professor Id:  1707
# Professor Id:  602
# Professor Id:  603
# Professor Id:  1798
# Professor Id:  3036
# Professor Id:  2392
# Professor Id:  1352
# Professor Id:  2962
# Professor Id:  2609
# Professor Id:  604
# Professor Id:  4153
# Professor Id:  2823
# Professor Id:  1036
# Professor Id:  1595
# Professor Id:  1009
# Professor Id:  605
# Professor Id:  1757
# Professor Id:  1267
# Professor Id:  606
# Professor Id:  607
# Professor Id:  2690
# Professor Id:  2681
# Professor Id:  2921
# Professor Id:  3072
# Professor Id:  608
# Professor Id:  4179
# Professor Id:  4177
# Professor Id:  3103
# Professor Id:  612
# Professor Id:  610
# Professor Id:  611
# Professor Id:  613
# Professor Id:  1735
# Professor Id:  4158
# Professor Id:  3998
# Professor Id:  614
# Professor Id:  3485
# Professor Id:  1052
# Professor Id:  615
# Professor Id:  616
# Professor Id:  1469
# Professor Id:  1250
# Professor Id:  3106
# Professor Id:  1116
# Professor Id:  617
# Professor Id:  3499
# Professor Id:  1354
# Professor Id:  3514
# Professor Id:  1653
# Professor Id:  1501
# Professor Id:  863
# Professor Id:  902
# Professor Id:  619
# Professor Id:  618
# Professor Id:  3686
# Professor Id:  3666
# Professor Id:  2060
# Professor Id:  3899
# Professor Id:  3461
# Professor Id:  620
# Professor Id:  4078
# Professor Id:  4042
# Professor Id:  621
# Professor Id:  2629
# Professor Id:  1454
# Professor Id:  622
# Professor Id:  3102
# Professor Id:  837
# Professor Id:  1442
# Professor Id:  1056
# Professor Id:  623
# Professor Id:  994
# Professor Id:  995
# Professor Id:  3749
# Professor Id:  624
# Professor Id:  625
# Professor Id:  2754
# Professor Id:  2120
# Professor Id:  3508
# Professor Id:  991
# Professor Id:  626
# Professor Id:  1233
# Professor Id:  1240
# Professor Id:  4206
# Professor Id:  1708
# Professor Id:  996
# Professor Id:  1517
# Professor Id:  2839
# Professor Id:  1790
# Professor Id:  824
# Professor Id:  627
# Professor Id:  628
# Professor Id:  2830
# Professor Id:  2068
# Professor Id:  1463
# Professor Id:  829
# Professor Id:  2157
# Professor Id:  2538
# Professor Id:  629
# Professor Id:  1134
# Professor Id:  1467
# Professor Id:  630
# Professor Id:  3962
# Professor Id:  631
# Professor Id:  632
# Professor Id:  944
# Professor Id:  4188
# Professor Id:  633
# Professor Id:  2991
# Professor Id:  634
# Professor Id:  635
# Professor Id:  1290
# Professor Id:  636
# Professor Id:  3537
# Professor Id:  1479
# Professor Id:  637
# Professor Id:  1827
# Professor Id:  4069
# Professor Id:  638
# Professor Id:  639
# Professor Id:  1091
# Professor Id:  2857
# Professor Id:  640
# Professor Id:  1754
# Professor Id:  641
# Professor Id:  2381
# Professor Id:  2865
# Professor Id:  977
# Professor Id:  642
# Professor Id:  756
# Professor Id:  1160
# Professor Id:  2960
# Professor Id:  801
# Professor Id:  1388
# Professor Id:  914
# Professor Id:  1692
# Professor Id:  1727
# Professor Id:  2677
# Professor Id:  989
# Professor Id:  2699
# Professor Id:  3005
# Professor Id:  643
# Professor Id:  1730
# Professor Id:  1651
# Professor Id:  2115
# Professor Id:  1919
# Professor Id:  2737
# Professor Id:  1612
# Professor Id:  644
# Professor Id:  2079
# Professor Id:  645
# Professor Id:  646
# Professor Id:  2112
# Professor Id:  1135
# Professor Id:  647
# Professor Id:  648
# Professor Id:  2109
# Professor Id:  1048
# Professor Id:  1988
# Professor Id:  649
# Professor Id:  3974
# Professor Id:  1586
# Professor Id:  2622
# Professor Id:  1672
# Professor Id:  1231
# Professor Id:  1546
# Professor Id:  3895
# Professor Id:  2992
# Professor Id:  1520
# Professor Id:  2893
# Professor Id:  2434
# Professor Id:  650
# Professor Id:  651
# Professor Id:  1680
# Professor Id:  3915
# Professor Id:  1175
# Professor Id:  652
# Professor Id:  825
# Professor Id:  2919
# Professor Id:  834
# Professor Id:  3041
# Professor Id:  793
# Professor Id:  2887
# Professor Id:  654
# Professor Id:  4106
# Professor Id:  655
# Professor Id:  1478
# Professor Id:  656
# Professor Id:  3981
# Professor Id:  657
# Professor Id:  2972
# Professor Id:  3396
# Professor Id:  2903
# Professor Id:  1099
# Professor Id:  4110
# Professor Id:  1880
# Professor Id:  2451
# Professor Id:  1259
# Professor Id:  658
# Professor Id:  1180
# Professor Id:  1307
# Professor Id:  1647
# Professor Id:  659
# Professor Id:  663
# Professor Id:  660
# Professor Id:  1268
# Professor Id:  661
# Professor Id:  662
# Professor Id:  3495
# Professor Id:  664
# Professor Id:  665
# Professor Id:  906
# Professor Id:  3148
# Professor Id:  2873
# Professor Id:  3393
# Professor Id:  667
# Professor Id:  1645
# Professor Id:  4133
# Professor Id:  2783
# Professor Id:  2855
# Professor Id:  1826
# Professor Id:  668
# Professor Id:  1291
# Professor Id:  2446
# Professor Id:  962
# Professor Id:  669
# Professor Id:  670
# Professor Id:  736
# Professor Id:  671
# Professor Id:  672
# Professor Id:  673
# Professor Id:  1887
# Professor Id:  3116
# Professor Id:  4017
# Professor Id:  1683
# Professor Id:  1584
# Professor Id:  4135
# Professor Id:  674
# Professor Id:  675
# Professor Id:  961
# Professor Id:  1464
# Professor Id:  3062
# Professor Id:  1912
# Professor Id:  887
# Professor Id:  862
# Professor Id:  676
# Professor Id:  3977
# Professor Id:  677
# Professor Id:  784
# Professor Id:  678
# Professor Id:  679
# Professor Id:  4053
# Professor Id:  680
# Professor Id:  2955
# Professor Id:  2630
# Professor Id:  681
# Professor Id:  682
# Professor Id:  2085
# Professor Id:  2061
# Professor Id:  1494
# Professor Id:  3022
# Professor Id:  3988
# Professor Id:  3992
# Professor Id:  2715
# Professor Id:  683
# Professor Id:  3356
# Professor Id:  1248
# Professor Id:  684
# Professor Id:  685
# Professor Id:  1132
# Professor Id:  3309
# Professor Id:  4195
# Professor Id:  686
# Professor Id:  2029
# Professor Id:  1102
# Professor Id:  1115
# Professor Id:  1505
# Professor Id:  4054
# Professor Id:  1415
# Professor Id:  687
# Professor Id:  688
# Professor Id:  689
# Professor Id:  690
# Professor Id:  2410
# Professor Id:  1022
# Professor Id:  691
# Professor Id:  1199
# Professor Id:  692
# Professor Id:  4138
# Professor Id:  3920
# Professor Id:  693
# Professor Id:  4096
# Professor Id:  851
# Professor Id:  3973
# Professor Id:  694
# Professor Id:  2545
# Professor Id:  2508
# Professor Id:  753
# Professor Id:  695
# Professor Id:  696
# Professor Id:  697
# Professor Id:  698
# Professor Id:  3469
# Professor Id:  1001
# Professor Id:  4214
# Professor Id:  3384
# Professor Id:  3445
# Professor Id:  699
# Professor Id:  700
# Professor Id:  2774
# Professor Id:  1532
# Professor Id:  1522
# Professor Id:  2980
# Professor Id:  939
# Professor Id:  1451
# Professor Id:  870
# Professor Id:  1431
# Professor Id:  1473
# Professor Id:  967
# Professor Id:  2037
# Professor Id:  935
# Professor Id:  4029
# Professor Id:  2365
# Professor Id:  701
# Professor Id:  2071
# Professor Id:  2805
# Professor Id:  2787
# Professor Id:  702
# Professor Id:  703
# Professor Id:  2506
# Professor Id:  854
# Professor Id:  2898
# Professor Id:  1581
# Professor Id:  704
# Professor Id:  705
# Professor Id:  952
# Professor Id:  2140
# Professor Id:  706
# Professor Id:  707
# Professor Id:  3711
# Professor Id:  709
# Professor Id:  708
# Professor Id:  710
# Professor Id:  711
# Professor Id:  2726
# Professor Id:  712
# Professor Id:  1197
# Professor Id:  1620
# Professor Id:  1905
# Professor Id:  3174
# Professor Id:  713
# Professor Id:  4102
# Professor Id:  2925
# Professor Id:  2247
# Professor Id:  783
# Professor Id:  714
# Professor Id:  2890
# Professor Id:  958
# Professor Id:  1251
# Professor Id:  1824
# Professor Id:  2090
# Professor Id:  715
# Professor Id:  3007
# Professor Id:  1085
# Professor Id:  716
# Professor Id:  2164
# Professor Id:  2516
# Professor Id:  4013
# Professor Id:  4068
# Professor Id:  4166
# Professor Id:  2110
# Professor Id:  3498
# Professor Id:  1034
# Professor Id:  1375
# Professor Id:  2203
# Professor Id:  4108
# Professor Id:  718
# Professor Id:  1549
# Professor Id:  3402
# Professor Id:  2361
# Professor Id:  1417
# Professor Id:  4052
# Professor Id:  3112
# Professor Id:  847
# Professor Id:  719
# Professor Id:  720
# Professor Id:  2943
# Professor Id:  2441
# Professor Id:  721
# Professor Id:  4098
# Professor Id:  3965
# Professor Id:  821
# Professor Id:  805
# Professor Id:  775
# Professor Id:  3076
# Professor Id:  1100
# Professor Id:  1420
# Professor Id:  3416
# Professor Id:  2095
# Professor Id:  722
# Professor Id:  2763
# Professor Id:  3105
# Professor Id:  723
# Professor Id:  724
# Professor Id:  1687
# Professor Id:  1593
# Professor Id:  2104
# Professor Id:  2905
# Professor Id:  1258
# Professor Id:  3045
# Professor Id:  725
# Professor Id:  726
# Professor Id:  3027
# Professor Id:  727
# Professor Id:  1758
# Professor Id:  728

# %%
professor_reviews[14].head()
# Out:
#                                               Review Grade review_id  \
# 0  Dr. Agronsky is a great professor! His class i...   N/A     47437
# 0  he does not know how to teach. after waitlisti...     F     47144
# 0  Dr. Agronsky was simply amazing. I was in his ...     A     41076
# 0  Agronsky is a wonderful teacher. Unfortunately...     C     40991
# 0  One of the best professors here at Cal Poly. T...   N/A     40806
#
#      Course       Year  prof_id
# 0  MATH 142   Freshman        5
# 0  MATH 142   Freshman        5
# 0  MATH 241   Freshman        5
# 0  MATH 241   Freshman        5
# 0  MATH 241  Sophomore        5

# %% [markdown]
# # Surprise! Not all professors have a full statistical analysis page.
# This code deletes professors that don't have full statistical analysis pages. Otherwise, we would have trouble merging DataFrames later on.

# %%
len(professor_reviews)
u_profs_previews = []
for p in professor_reviews:
    u_profs_previews.append(p.prof_id.unique()[0])
    
print(len(u_profs_previews))

u_profs_gl = []
for p in p_stats_by_grade_list:
    u_profs_gl.append(p.prof_id.unique()[0])

print(len(u_profs_gl))

no_full_stat_analyses = list(set(u_profs_previews) - set(u_profs_gl))
print(len(no_full_stat_analyses))
# no_full_stat_analyses[2]
# Out:
# 2416
# 1755
# 661

# %% [markdown]
# We can get remove the professors that don't have full statistical analysis pages from the professor_reviews list of DataFrames.
#
# This will allow us to merge each professor_reviews DataFrame with a DataFrame from the p_stats_by_grade_list.
#
# The benefit of doing this is to organize grades and professor reviews into the same DataFrame.
#
# The following code takes care of this.

# %%
def remove_bad_entries(): 
     '''
     Remove professors that don't have the full statistical analysis in professor_reviews list. 
     This is usually caused by having less than 5 reviews.
     Args: None
     Returns: removals (int): number of professors removed from the professor_reviews list. 
     '''
    removals = 0
    for index, p in enumerate(professor_reviews):
        if p.prof_id.values[0] in no_full_stat_analyses:
            removals += 1
            del professor_reviews[index]

    print('Removed ', removals, ' professors.')
    return removals
# Out:
# Removed  0  professors.

# %%
n = remove_bad_entries()
while n > 0:
    n = remove_bad_entries()
# Out:
# Removed  0  professors.

# %%
assert len(professor_reviews) == len(p_stats_by_grade_list)
assert u_profs_gl[-1] == u_profs_previews[-1]

# %% [markdown]
# # Below is time-consuming code
# More webscraping is involved to get the text reviews for each professor.

# %%
reviews_by_grade = get_reviews_by_grade(professor_reviews, p_stats_by_grade_list)
# Out:
# n =  1755

# %%
reviews_by_grade.tail()
# Out:
#                                                       Review Grade    Course  \
# review_id
# 29816      Zumwalt's class was extremely difficult for me...     C  CHEM 124
# 29445      Well.. 124 is a hard class but I actually real...     C  CHEM 124
# 31360      Zumwalt is alright, but she isn't the greatest...     D  CHEM 124
# 29647      Before I start this is not an angry spiteful e...   N/A  CHEM 124
# 26349      You can tell she is a new teacher.  She is ver...   N/A  CHEM 124
#
#                 Year  prof_id Presents Material Clearly Overall Rating  \
# review_id
# 29816       Freshman     1758                     3.667          3.667
# 29445       Freshman     1758                     3.667          3.667
# 31360      Sophomore     1758                         2              2
# 29647       Freshman     1758                       0.5              1
# 26349       Freshman     1758                       0.5              1
#
#           Recognizes Student Difficulties Reporting Evaluations
# review_id
# 29816                                   3                     3
# 29445                                   3                     3
# 31360                                   2                     1
# 29647                                   1                     2
# 26349                                   1                     2

# %% [markdown]
# ## Quick! Write it all to json in the /data folder under a personalized directory. Let's have two files just in case the first one ever gets corrupted.

# %%
create_jsons('/data/primitiveDataType/data.json', \
             [professors, p_stats, p_stats_by_grade_list, reviews_by_grade])

# %%
create_jsons('/data/primitiveDataType/data1.json', \
             [professors, p_stats, p_stats_by_grade_list, reviews_by_grade])
